# %% [markdown]
# > LangChain Ollama: <https://python.langchain.com/docs/integrations/providers/ollama/>

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

# %%
template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="gemma3n:latest", base_url="http://localhost:11434") # 도커를 이용하고 있으므로 base_url을 지정해주어야 함

chain = prompt | model

answer = chain.invoke({"question": "What is LangChain? Speak in Korean!"})

# %%
answer
# Out:
# '## LangChain에 대해 설명해 드릴게요! (Let\'s explain LangChain!)\n\nLangChain은 **대규모 언어 모델(LLM)을 활용하여 다양한 애플리케이션을 구축하기 위한 프레임워크**입니다. 쉽게 말해, ChatGPT나 Bard 같은 AI 모델을 더 강력하고 유용하게 사용할 수 있도록 도와주는 도구 모음이라고 생각하면 됩니다.\n\n**좀 더 자세히 설명하자면:**\n\n* **LLM과의 연결:** LangChain은 LLM과 다양한 데이터 소스(문서, 데이터베이스, API 등)를 연결하는 데 도움을 줍니다.  LLM이 단순히 텍스트를 생성하는 것뿐만 아니라, 외부 정보를 활용하여 더 정확하고 맥락에 맞는 답변을 제공하도록 하는 것이죠.\n* **체인(Chain) 구성:**  LangChain의 핵심 개념은 "체인"입니다. 여러 개의 구성 요소(예: LLM, 데이터 로더, 임베딩 모델, 메모리 등)를 연결하여 복잡한 작업을 수행하는 파이프라인을 만들 수 있습니다. 예를 들어, 문서에서 정보를 추출하고, 요약하고, 질문에 답변하는 체인을 만들 수 있습니다.\n* **다양한 기능 제공:** LangChain은 문서 로딩, 텍스트 분할, 임베딩 생성, 프롬프트 관리, 메모리 관리, 에이전트 등 다양한 기능을 제공합니다.  이러한 기능을 활용하여 챗봇, 문서 요약기, 질문 답변 시스템 등 다양한 애플리케이션을 만들 수 있습니다.\n\n**LangChain을 사용하면 다음과 같은 장점이 있습니다:**\n\n* **개발 효율성 향상:**  LLM 애플리케이션 개발에 필요한 다양한 구성 요소를 미리 만들어 제공하므로 개발 시간을 단축할 수 있습니다.\n* **유연성:** 다양한 LLM과 데이터 소스를 지원하므로 원하는 대로 애플리케이션을 구축할 수 있습니다.\n* **확장성:**  새로운 기능과 구성 요소를 쉽게 추가할 수 있으므로 애플리케이션을 확장하기 용이합니다.\n\n**간단하게 요약하자면, LangChain은 LLM을 활용한 애플
# ...

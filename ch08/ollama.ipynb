# %% [markdown]
# > LangChain Ollama: <https://python.langchain.com/docs/integrations/providers/ollama/>

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

# %%
template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="gpt-oss:20b", base_url="http://localhost:11434") # 도커를 이용하고 있으므로 base_url을 지정해주어야 함

chain = prompt | model

answer = chain.invoke({"question": "What is LangChain? Speak in Korean!"})

# %%
answer
# Out:
# '**LangChain이란?**  \n아래 단계별로 정리해 드리겠습니다.\n\n---\n\n## 1️⃣ 정의  \n**LangChain**은 **대형 언어 모델(Large Language Model, LLM)**을 활용한 애플리케이션을 쉽게 구축할 수 있도록 도와주는 **Python 기반 오픈소스 프레임워크**입니다.  \n- **주요 목표**: LLM을 이용한 대화형 AI, 문서 검색, 추론 등 복잡한 워크플로를 단순화하고, 재사용 가능한 컴포넌트(Chain, Tool, Prompt, Memory 등)를 제공함.\n\n---\n\n## 2️⃣ 핵심 개념  \n| 개념 | 설명 |\n|------|------|\n| **Chain** | 입력→처리→출력 과정을 하나의 순차적 흐름으로 묶은 객체. 예) `RetrievalQA`, `ChatChain` |\n| **Prompt** | LLM에 전달되는 텍스트(질문·명령). Prompt Engineering을 손쉽게 적용할 수 있음. |\n| **Memory** | 대화 상태나 문맥을 기억하도록 설계된 모듈. 예) `ConversationBufferMemory` |\n| **Tool** | LLM이 호출할 수 있는 외부 기능(API 호출, 데이터베이스 쿼리 등). |\n| **LLM** | 실제 LLM 인스턴스(`OpenAI`, `Anthropic`, `HuggingFace` 등)와 연결. |\n| **Vector Store** | 문서 검색을 위해 임베딩된 벡터를 저장하고 조회하는 저장소. 예) `FAISS`, `Chroma`, `Pinecone` |\n\n---\n\n## 3️⃣ 작동 흐름 예시  \n1. **Prompt** → LLM → **Response**  \n2. **Chain** 내부에서 필요 시 **Vector Store**에 질의 → 문서 검색  \n3. 검색된 문서 → LLM에 보강된 Prompt 전달 → 최종 답변 생성  \n4. **Memory**에 대화 상태 저장 → 다음 질문에 활용  \n\n이러한 흐름을 하나의 객체(`Chain`)로 묶어 재사용이 가능하다.\n\n---\n\n## 4️⃣ 사용 사례  \n| 분야 | 예시 |\n|------|------|\n| **문서 기반 QA** | 기업 내부 정책 문서 검색 & 질문응답 |\n| **챗봇** | 고객 지원, 기술 지원 자동화 |\n| **코드 자동 생성** | API 문서를 기반으로 코드 스니펫 생성 |\n| **데이터 분석** | 대량 데이터에서 인사이트 추출, 시각화 |\n| **교육** | 학습 자료 기반 맞춤형 질문/답변 |\n\n---\n\n## 5️⃣ 설치 & 시작하기  \n```bash\n# 가상환경 생성 (선택)\npython -m venv langchain-env\nsource langchain-env/bin/activate   # Windows는 .\\langchain-env\\Scripts\\activate\n\n# 패키지 설치\npip install langchain[all]   # 기본 + 모든 optional extras 설치\n```\n\n### 간단한 예시 코드\n```python\nfrom langchain.llms import OpenAI\nfrom langchain.chains import RetrievalQA\nfrom langchain.vectorstores import FAISS\nfrom langchain.embeddings import OpenAIEmbeddings\n\n# LLM 초기화\nllm = OpenAI(model="gpt-4o-mini", temperature=0.1)\n\n# 벡터 저장소 준비\nembeddings = OpenAIEmbeddings()\ndocstore = FAISS.from_documents(docs, embeddings)  # docs는 사전 준비된 Document 리스트\n\n# RetrievalQA 체인 생성\nchain = RetrievalQA.from_chain_type(\n    llm=llm,\n    chain_type="stuff",\n    retriever=docstore.as_retriever(),\n)\n\n# 질문 실행\nresponse = chain({"question": "최근 재무 보고서에서 주요 이슈는?"})\nprint(response["result"])\n```\n\n---\n\n## 6️⃣ 장점  \n- **모듈화**: Chain, Prompt, Tool 등을 재사용 가능.  \n- **플러그인 방식**: 새로운 LLM, 벡터 저장소, API 등 쉽게 연결.  \n- **문서화 및 예제 풍부**: 초보자부터 전문가까지 활용 가능한 자료 제공.  \n- **오픈소스**: 커뮤니티 기반 개선, 투명한 개발.\n\n---\n\n## 7️⃣ 단점 & 주의사항  \n- **학습곡선**: 개념(Chain, Memory, Tool) 이해 필요.  \n- **비용**: 대형 LLM 호출에 따라 비용이 발생.  \n- **퍼포먼스**: 복잡한 체인에서 지연 시간이 커질 수 있음.  \n- **보안**: 외부 API 호출 시 민감 데이터 유출 위험 주의.\n\n---\n\n## 8️⃣ 마무리  \nLangChain은 **LLM 기반 애플리케이션 개발을 가속화**해 주는 프레임워크로, **전문가가 아니더라도 구조화된 워크플로를 손쉽게 구축**할 수 있게 해줍니다.  \n프로그래밍 지식이 있는 분이라면 빠르게 시도해보고, 문서와 예제들을 통해 실제 비즈니스에 맞는 응용을 확장해 보세요!'

# %% [markdown]
# > LangChain Ollama: <https://python.langchain.com/docs/integrations/providers/ollama/>

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

# %%
template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="gemma3n:latest", base_url="http://localhost:11434") # 도커를 이용하고 있으므로 base_url을 지정해주어야 함

chain = prompt | model

answer = chain.invoke({"question": "What is LangChain? Speak in Korean!"})

# %%
answer
# Out:
# '네, 좋습니다! LangChain에 대해 한국어로 설명해 드릴게요.\n\n**LangChain은 쉽게 말해, 대규모 언어 모델(LLM)을 활용해서 다양한 작업을 수행할 수 있도록 도와주는 프레임워크입니다.** LLM은 ChatGPT처럼 텍스트를 이해하고 생성하는 AI 모델을 말합니다.\n\n**좀 더 자세히 설명하면:**\n\n*   **LLM과 다른 도구 연결:** LangChain은 LLM을 단순히 텍스트 생성기처럼 사용하는 것이 아니라, 다른 데이터 소스 (예: 데이터베이스, 웹 페이지, API)와 연결하여 더 복잡한 작업을 수행할 수 있도록 해줍니다.\n*   **체인(Chain) 구성:** 여러 개의 작업을 연결하여 하나의 파이프라인처럼 작동하도록 만들 수 있습니다. 예를 들어, 질문을 받고, 관련 정보를 검색하고, 그 정보를 바탕으로 답변을 생성하는 과정을 하나의 체인으로 구성할 수 있습니다.\n*   **다양한 기능 제공:**  LangChain은 데이터 로딩, 텍스트 분할, 프롬프트 관리, 메모리 관리 등 다양한 기능을 제공하여 LLM 기반 애플리케이션 개발을 더 쉽게 만들어줍니다.\n*   **오픈 소스:**  오픈 소스이기 때문에 누구나 자유롭게 사용하고 기여할 수 있습니다.\n\n**LangChain을 사용하면 다음과 같은 작업을 할 수 있습니다:**\n\n*   **질의 응답 시스템 구축:**  문서나 데이터베이스에서 질문에 대한 답변을 찾도록 합니다.\n*   **챗봇 개발:**  사용자와 자연스러운 대화를 나누는 챗봇을 만들 수 있습니다.\n*   **데이터 분석:**  데이터를 분석하고 시각화하는 데 LLM을 활용할 수 있습니다.\n*   **자동화:**  반복적인 작업을 자동화하는 데 LLM을 활용할 수 있습니다.\n\n**요약하자면, LangChain은 LLM을 활용하여 더 강력하고 유용한 AI 애플리케이션을 개발할 수 있도록 도와주는 강력한 도구입니다.**\n\n더 궁금한 점이 있으시면 언제든지 질문해주세요!\n'

# %%
from pyzerox import zerox
import os
import json
import asyncio
from dotenv import load_dotenv

load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")
model = "gemini/gemini-2.5-flash"

# %%
gemini_api_key
# Out:
# 'AIzaSyDC7Aa_Rzru1GRN3Y92hU8FRquZVR_j7rc'

# %%
os.environ["GOOGLE_AI_API_KEY"] = gemini_api_key

# %%
for file_path in os.listdir("./data"):
    file_path = f"./data/{file_path}"
    print(file_path)
# Out:
# ./data/KCI_FI003153549.pdf

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
async def main():
    results = []
    for file_path in os.listdir("./data"):
        file_path = f"./data/{file_path}"
        
        kwargs = {}

        custom_system_prompt = None
        select_pages = None
        output_dir = "./output"
        print(file_path)
        result = await zerox(file_path=file_path, model=model, output_dir=output_dir,
                            custom_system_prompt=custom_system_prompt, select_pages=select_pages, **kwargs)
        
        results.append(result)
        print(f'{file_path} is done!')
    return result

result = asyncio.run(main())
# Out:
# ./data/KCI_FI003153549.pdf
# ERROR:root:Error converting PDF to images: Unable to get page count. Is poppler installed and in PATH?
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\dandy\Documents\GitHub\kor-it-langchain-class\ch08\.venv\Lib\site-packages\pdf2image\pdf2image.py:581, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     580     env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 581 proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     583 try:
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\subprocess.py:1554, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1553 try:
# -> 1554     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1555                              # no special security
#    1556                              None, None,
#    1557                              int(not close_fds),
#    1558                              creationflags,
#    1559                              env,
#    1560                              cwd,
#    1561                              startupinfo)
#    1562 finally:
#    1563     # Child is launched. Close the parent's copy of those pipe
#    1564     # handles that only the child should have open.  You need
#    (...)   1567     # pipe will not close when the child process exits and the
#    1568     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다
#
# During handling of the above exception, another exception occurred:
#
# PDFInfoNotInstalledError                  Traceback (most recent call last)
# File c:\Users\dandy\Documents\GitHub\kor-it-langchain-class\ch08\.venv\Lib\site-packages\pyzerox\processor\pdf.py:28, in convert_pdf_to_images(local_path, temp_dir)
#      27 try:
# ---> 28     image_paths = await asyncio.to_thread(
#      29         convert_from_path, **options
#      30     )
#      31     return image_paths
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\asyncio\threads.py:25, in to_thread(func, *args, **kwargs)
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\asyncio\futures.py:286, in Future.__await__(self)
#     285     self._asyncio_future_blocking = True
# --> 286     yield self  # This tells Task to wait for completion.
#     287 if not self.done():
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\asyncio\tasks.py:375, in Task.__wakeup(self, future)
#     374 try:
# --> 375     future.result()
#     376 except BaseException as exc:
#     377     # This may also be a cancellation.
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\asyncio\futures.py:199, in Future.result(self)
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#
# File c:\Users\dandy\Documents\GitHub\kor-it-langchain-class\ch08\.venv\Lib\site-packages\pdf2image\pdf2image.py:127, in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, ownerpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     125     poppler_path = poppler_path.as_posix()
# --> 127 page_count = pdfinfo_from_path(
#     128     pdf_path, userpw, ownerpw, poppler_path=poppler_path
#     129 )["Pages"]
#     131 # We start by getting the output format, the buffer processing function and if we need pdftocairo
#
# File c:\Users\dandy\Documents\GitHub\kor-it-langchain-class\ch08\.venv\Lib\site-packages\pdf2image\pdf2image.py:607, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     606 except OSError:
# --> 607     raise PDFInfoNotInstalledError(
#     608         "Unable to get page count. Is poppler installed and in PATH?"
#     609     )
#     610 except ValueError:
#
# PDFInfoNotInstalledError: Unable to get page count. Is poppler installed and in PATH?
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 19
#      16         print(f'{file_path} is done!')
#      17     return result
# ---> 19 result = asyncio.run(main())
#
# File c:\Users\dandy\Documents\GitHub\kor-it-langchain-class\ch08\.venv\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File c:\Users\dandy\Documents\GitHub\kor-it-langchain-class\ch08\.venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\asyncio\tasks.py:306, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     304         result = coro.send(None)
#     305     else:
# --> 306         result = coro.throw(exc)
#     307 except StopIteration as exc:
#     308     if self._must_cancel:
#     309         # Task is cancelled right before coro stops.
#
# Cell In[4], line 12, in main()
#      10 output_dir = "./output"
#      11 print(file_path)
# ---> 12 result = await zerox(file_path=file_path, model=model, output_dir=output_dir,
#      13                     custom_system_prompt=custom_system_prompt, select_pages=select_pages, **kwargs)
#      15 results.append(result)
#      16 print(f'{file_path} is done!')
#
# File c:\Users\dandy\Documents\GitHub\kor-it-langchain-class\ch08\.venv\Lib\site-packages\pyzerox\core\zerox.py:149, in zerox(cleanup, concurrency, file_path, maintain_format, model, output_dir, temp_dir, custom_system_prompt, select_pages, **kwargs)
#     147             aggregated_markdown.append(result)
#     148 else:
# --> 149     results = await process_pages_in_batches(
#     150         images,
#     151         concurrency,
#     152         vision_model,
#     153         temp_directory,
#     154         input_token_count,
#     155         output_token_count,
#     156         prior_page,
#     157     )
#     159     aggregated_markdown = [result[0] for result in results if isinstance(result[0], str)]
#     161     ## add token usage
#
# File c:\Users\dandy\Documents\GitHub\kor-it-langchain-class\ch08\.venv\Lib\site-packages\pyzerox\processor\pdf.py:104, in process_pages_in_batches(images, concurrency, model, temp_directory, input_token_count, output_token_count, prior_page)
#      91 semaphore = asyncio.Semaphore(concurrency)
#      93 # Process each page in parallel
#      94 tasks = [
#      95     process_page(
#      96         image,
#      97         model,
#      98         temp_directory,
#      99         input_token_count,
#     100         output_token_count,
#     101         prior_page,
#     102         semaphore,
#     103     )
# --> 104     for image in images
#     105 ]
#     107 # Wait for all tasks to complete
#     108 return await asyncio.gather(*tasks)
#
# TypeError: 'NoneType' object is not iterable

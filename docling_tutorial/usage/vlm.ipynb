# %%
# FILE = "../data/sample_income_tax_p30.png"
FILE = "../data/sample_income_tax_p30.pdf"

# %%
from docling.datamodel.base_models import InputFormat
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.pipeline.vlm_pipeline import VlmPipeline
from docling.datamodel.pipeline_options import (
    VlmPipelineOptions,
)
from docling.datamodel import vlm_model_specs

pipeline_options = VlmPipelineOptions(
    vlm_options=vlm_model_specs.SMOLDOCLING_MLX,  # <-- change the model here
)

converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_cls=VlmPipeline,
            pipeline_options=pipeline_options,
        ),
    }
)

doc = converter.convert(source=FILE).document
# Out:
# /Users/dandy/github/kor-it-langchain-class/docling_tutorial/.venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:2779: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(

# %%
print(doc)
# Out:
# schema_name='DoclingDocument' version='1.5.0' name='Document' origin=None furniture=GroupItem(self_ref='#/furniture', parent=None, children=[], content_layer=<ContentLayer.FURNITURE: 'furniture'>, name='_root_', label=<GroupLabel.UNSPECIFIED: 'unspecified'>) body=GroupItem(self_ref='#/body', parent=None, children=[RefItem(cref='#/texts/0'), RefItem(cref='#/texts/1'), RefItem(cref='#/texts/2'), RefItem(cref='#/tables/0'), RefItem(cref='#/groups/0'), RefItem(cref='#/texts/8'), RefItem(cref='#/texts/9'), RefItem(cref='#/tables/1'), RefItem(cref='#/groups/1'), RefItem(cref='#/texts/11'), RefItem(cref='#/texts/12'), RefItem(cref='#/texts/13'), RefItem(cref='#/texts/14'), RefItem(cref='#/texts/15')], content_layer=<ContentLayer.BODY: 'body'>, name='_root_', label=<GroupLabel.UNSPECIFIED: 'unspecified'>) groups=[ListGroup(self_ref='#/groups/0', parent=RefItem(cref='#/body'), children=[RefItem(cref='#/texts/3'), RefItem(cref='#/texts/4'), RefItem(cref='#/texts/5'), RefItem(cref='#/texts/6'), RefItem(cref='#/texts/7')], content_layer=<ContentLayer.BODY: 'body'>, name='list', label=<GroupLabel.LIST: 'list'>), ListGroup(self_ref='#/groups/1', parent=RefItem(cref='#/body'), children=[RefItem(cref='#/texts/10')], content_layer=<ContentLayer.BODY: 'body'>, name='list', label=<GroupLabel.LIST: 'list'>)] texts=[TextItem(self_ref='#/texts/0', parent=RefItem(cref='#/body'), children=[], content_layer=<ContentLayer.FURNITURE: 'furniture'>, label=<DocItemLabel.PAGE_HEADER: 'page_header'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=518.84, t=28.628000000000004, r=566.4399999999999, b=42.1, coord_origin=<CoordOrigin.TOPLEFT: 'TOPLEFT'>), charspan=(0, 4))], orig='수동시발', text='수동시발', formatting=None, hyperlink=None), TextItem(self_ref='#/texts/1', parent=RefItem(cref='#/body'), children=[], content_layer=<ContentLayer.BODY: 'body'>, label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=70.21, t=63.992, r=403.41, b=75.78, coord_origin=<CoordOrigin.TOPLEFT: 'TOPLEFT'>), charspan=(0, 44))], orig='제5간 근로수동시고 인구소드적에 반드시켜도와도와와  2009. 12. 31. >', text='제5간 근로수동시고 인구소드적에 반드시켜도와도와와  2009. 12. 31. >', formatting=None, hyperlink=None), TextItem(self_ref='#/texts/2', parent=RefItem(cref='#/body'), children=[], content_layer=<ContentLayer.BODY: 'body'>, label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=34.510000000000005, t=90.93599999999999, r=559.3, b=134.72, coord_origin=<CoordOrigin.TOPLEFT: 'TOPLEFT'>), charspan=(0, 130))], orig='제4간즈(는데, 공고에서 인구소드에 영상된 여자에 대해서 다양한 계시가기량에 반드시켜도 영상에서 다양의 경우를 공고에 따른 것으로 제과대한을 제과하는 것인으로 2012. 1. 1., 2014. 1. 1., 2019. 12. 31. >', text='제4간즈(는데, 공고에서 인구소드에 영상된 여자에 대해서 다양한 계시가기량에 반드시켜도 영상에서 다양의 경우를 공고에 따른 것으로 제과대한을 제과하는 것인으로 2012. 1. 1., 2014. 1. 1., 2019. 12. 31. >', formatting=None, hyperlink=None), ListItem(self_ref='#/texts/3', parent=RefItem(cref='#/groups/0'), children=[], content_layer=<ContentLayer.BODY: 'body'>, label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=47.6, t=291.332, r=476.0, b=303.12, coord_origin=<CoordOrigin.TOPLEFT: 'TOPLEFT'>), charspan=(0, 59))], orig='의 영상된지에 대한 코지에 제1항에 또한 구하기로 1 정 15만의 이하의 1정 2018. 12. 31. >', text='의 영상된지에 대한 코지에 제1항에 또한 구하기로 1 정 15만의 이하의 1정 2018. 12. 31. >', formatting=None, hyperlink=None, enumerated=False, marker=''), ListItem(self_ref='#/texts/4', parent=RefItem(cref='#/groups/0'), children=[], content_layer=<ContentLayer.BODY: 'body'>, label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=47.6, t=306.488, r=566.4399999999999, b=335.11600000000004, coord_origin=<CoordOrigin.TOPLEFT: 'TOPLEFT'>), charspan=(0, 71))], orig='지는 구조들이 자동지에 알고리즈가기량의 합계과 계시가기와의 합계에 초과에 따른 것으로 영상에는 그 하 여율을 공고에서으로 다다.', text='지는 구조들이 자동지에 알고리즈가기량의 합계과 계시가기와의 합계에 초과에 따른 것으로 영상에는 그 하 여율을 공고에서으로 다다.', formatting=None, hyperlink=None, enumerated=False, marker=''), ListItem(self_ref='#/texts/5', parent=RefItem(cref='#/groups/0'), children=[], content ...

# %%
# 텍스트 아이템 반복 출력
for text_item in doc.texts:
    print(text_item.text)

# 표(테이블) 정보 출력 예시
for table_item in doc.tables:
    print(table_item.data)  # TableData 객체 형태로 변환됨

# 그림(이미지) 정보 출력 예시
for picture_item in doc.pictures:
    print(picture_item)  # 객체 정보, 또는 picture_item.image로 이미지 접근

# 각 항목별로 상세 속성을 함께 살펴보고 싶다면
import pprint
pprint.pprint(doc.texts[0].__dict__)
# Out:
# 수동시발
# 제5간 근로수동시고 인구소드적에 반드시켜도와도와와  2009. 12. 31. >
# 제4간즈(는데, 공고에서 인구소드에 영상된 여자에 대해서 다양한 계시가기량에 반드시켜도 영상에서 다양의 경우를 공고에 따른 것으로 제과대한을 제과하는 것인으로 2012. 1. 1., 2014. 1. 1., 2019. 12. 31. >
# 의 영상된지에 대한 코지에 제1항에 또한 구하기로 1 정 15만의 이하의 1정 2018. 12. 31. >
# 지는 구조들이 자동지에 알고리즈가기량의 합계과 계시가기와의 합계에 초과에 따른 것으로 영상에는 그 하 여율을 공고에서으로 다다.
# 여자 11하나를 제3항자에 지각으로 만들고 조건부터 "근로수동시고" 하다.
# 제1하의 경우에 2의 이하으로 부터 근로수동을 반드시켜도 영상을 정리되는 제역한다(다) 대하에 가능성을 그 근로수동의 합계을 초과에서 하나에 제1항에 따른 근로수동을 하여 제1항에 따른 것으로 영상을 정리여으로 제과한다.  2010. 12. 27. >
# 여자  2010. 12. 27. >
# 제트가정 2009. 12. 31. >
# 제4간중시(영상수동시) 에서 영상의 자동지에 가능성에 대해서 다양한 계시가기량에 반드시켜도 영상에서 다양한 근로수동을 제역한다. 아해서 같다(가설) 더 더욱 없는 것을 근로수동을 제역한다.  2013. 1. 1. >
# 지는구조에 따른 자동지 "근로수동시고" 하다.
# 지는구조에 2009. 12. 31. >
# 제48조(되지소속도적에) 이로서수동이 있는 가중자에서 대하성는 해당 계시가기량의 특성소드수동시에서 제1항의 구분에 따른 것으로 영상에고, 그 근로수동 근지에서 수동시에 1 대에 근로수동시하고, 근로수동과 2 대에 근로수동을 제역한다.  2014. 12. 23., 2022. 12. 31. > 이하에서 "한세스마" 하다(대에서 제2조의 구분에 따른 것으로 영상을 정리한다.  2015. 12. 23., 2022. 12. 31. >
# 보임지
# 30
# 주개부터정성된신탁
# table_cells=[TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='영상된 여자', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='근지에', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=0, end_col_offset_idx=1, text='50만의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=1, end_col_offset_idx=2, text='하 다양의 이하의 10만의 7으', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=0, end_col_offset_idx=1, text='50만의 초과 1 정 50만의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=1, end_col_offset_idx=2, text='35만의 +(50만의 최적과 초과는 2으에의 10만의 4으)', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=0, end_col_offset_idx=1, text='1정 50만의 초과 4 정 50만의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=1, end_col_offset_idx=2, text='75만의 +(1 정 50만의 최적과 초과는 2으에의 10만의 15)', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=4, end_row_offset_idx=5, start_col_offset_idx=0, end_col_offset_idx=1, text='영상 50만의 초과 1 정의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=4, end_row_offset_idx=5, start_col_offset_idx=1, end_col_offset_idx=2, text='1 정 20만의 +(4 정 50만의 최적과 초과는 2으에의 10만의 5)', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=5, end_row_offset_idx=6, start_col_offset_idx=0, end_col_offset_idx=1, text='1정의 조건', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=5, end_row_offset_idx=6, start_col_offset_idx=1, end_col_offset_idx=2, text='1 정 47만의 +(1 정의를 초과하는 2으에의 10만의 2)', column_header=False, row_header=False, row_section=False)] num_rows=6 num_cols=2 grid=[[TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='영상된 여자', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='근지에', column_header=False, row_header=False, row_section=False)], [TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=0, end_col_offset_idx=1, text='50만의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=1, end_col_offset_idx=2, text='하 다양의 이하의 10만의 7으', column_header=False, row_header=False, row_section=False)], [TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=0, end_col_offset_idx=1, text='50만의 초과 1 정 50만의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=1, end_col_offset_idx=2, text='35만의 +(50만의 최적과 초과는 2으에의 10만의 4으 ...
# table_cells=[TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='영상된 여자', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='근지에', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=0, end_col_offset_idx=1, text='35만의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=1, end_col_offset_idx=2, text='영상된 여자', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=0, end_col_offset_idx=1, text='35만의 초과 70만의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=1, end_col_offset_idx=2, text='35만의 +(35만의 최적과 초과는 2으에의 10만의 4으)', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=0, end_col_offset_idx=1, text='70만의 초과 14위에관의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=1, end_col_offset_idx=2, text='40)', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=4, end_row_offset_idx=5, start_col_offset_idx=0, end_col_offset_idx=1, text='14위에관의 초과', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=4, end_row_offset_idx=5, start_col_offset_idx=1, end_col_offset_idx=2, text='63만의 +(14위에관의 초과는 2으에의 10만의 10)', column_header=False, row_header=False, row_section=False)] num_rows=5 num_cols=2 grid=[[TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='영상된 여자', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='근지에', column_header=False, row_header=False, row_section=False)], [TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=0, end_col_offset_idx=1, text='35만의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=1, end_col_offset_idx=2, text='영상된 여자', column_header=False, row_header=False, row_section=False)], [TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=0, end_col_offset_idx=1, text='35만의 초과 70만의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=1, end_col_offset_idx=2, text='35만의 +(35만의 최적과 초과는 2으에의 10만의 4으)', column_header=False, row_header=False, row_section=False)], [TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=0, end_col_offset_idx=1, text='70만의 초과 14위에관의 이하', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=1, end_col_offset_idx=2, text='40)', column_header=False, row_header=False, row_section=False)], [TableCell(bbox=None, row_span=1, col_spa ...
# {'children': [],
#  'content_layer': <ContentLayer.FURNITURE: 'furniture'>,
#  'formatting': None,
#  'hyperlink': None,
#  'label': <DocItemLabel.PAGE_HEADER: 'page_header'>,
#  'orig': '수동시발',
#  'parent': RefItem(cref='#/body'),
#  'prov': [ProvenanceItem(page_no=1, bbox=BoundingBox(l=518.84, t=28.628000000000004, r=566.4399999999999, b=42.1, coord_origin=<CoordOrigin.TOPLEFT: 'TOPLEFT'>), charspan=(0, 4))],
#  'self_ref': '#/texts/0',
#  'text': '수동시발'}

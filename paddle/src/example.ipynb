# %%
# Initialize PaddleOCR instance
from paddleocr import PaddleOCR
ocr = PaddleOCR(
    use_doc_orientation_classify=False,
    use_doc_unwarping=False,
    use_textline_orientation=False)

# Run OCR inference on a sample image 
result = ocr.predict(
    input="../data/general_ocr_002.png")
# Out:
# Creating model: ('PP-OCRv5_server_det', None)
# Using official model (PP-OCRv5_server_det), the model files will be automatically downloaded and saved in `/Users/dandy/.paddlex/official_models/PP-OCRv5_server_det`.
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Encounter exception when download model from huggingface:
# <ContextVar name='shell_parent' at 0x107d02a70>.
# PaddleX would try to download from other model sources.
# Using official model (PP-OCRv5_server_det), the model files will be automatically downloaded and saved in `/Users/dandy/.paddlex/official_models/PP-OCRv5_server_det`.
# Processing 5 items:   0%|          | 0.00/5.00 [00:00<?, ?it/s]
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# [Download] Error downloading /var/folders/4p/swdn3py146z4xn6fx_rghdq40000gn/T/tmp54en69sz/temp_dir/._tmp/README.md: None: Max retries exceeded with url: https://git.aistudio.baidu.com/api/v1/repos/PaddleX/PP-OCRv5_server_det/media/README.md (Caused by LookupError(<ContextVar name='shell_parent' at 0x107d02a70>))
# [Download] Error downloading /var/folders/4p/swdn3py146z4xn6fx_rghdq40000gn/T/tmp54en69sz/temp_dir/._tmp/config.json: None: Max retries exceeded with url: https://git.aistudio.baidu.com/api/v1/repos/PaddleX/PP-OCRv5_server_det/media/config.json (Caused by LookupError(<ContextVar name='shell_parent' at 0x107d02a70>))
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# [Download] Error downloading /var/folders/4p/swdn3py146z4xn6fx_rghdq40000gn/T/tmp54en69sz/temp_dir/._tmp/inference.json: None: Max retries exceeded with url: https://git.aistudio.baidu.com/api/v1/repos/PaddleX/PP-OCRv5_server_det/media/inference.json (Caused by LookupError(<ContextVar name='shell_parent' at 0x107d02a70>))
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x111e9d240>
# Traceback (most recent call last):
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/dandy/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# [Download] Error downloading /var/folders/4p/swdn3py146z4xn6fx_rghdq40000gn/T/tmp54en69sz/temp_dir/._tmp/inference.pdiparams: None: Max retries exceeded with url: https://git.aistudio.baidu.com/api/v1/repos/PaddleX/PP-OCRv5_server_det/media/inference.pdiparams (Caused by LookupError(<ContextVar name='shell_parent' at 0x107d02a70>))
# [Download] Error downloading /var/folders/4p/swdn3py146z4xn6fx_rghdq40000gn/T/tmp54en69sz/temp_dir/._tmp/inference.yml: None: Max retries exceeded with url: https://git.aistudio.baidu.com/api/v1/repos/PaddleX/PP-OCRv5_server_det/media/inference.yml (Caused by LookupError(<ContextVar name='shell_parent' at 0x107d02a70>))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Initialize PaddleOCR instance
#       2 from paddleocr import PaddleOCR
# ----> 3 ocr = PaddleOCR(
#       4     use_doc_orientation_classify=False,
#       5     use_doc_unwarping=False,
#       6     use_textline_orientation=False)
#       8 # Run OCR inference on a sample image
#       9 result = ocr.predict(
#      10     input="../data/general_ocr_002.png")
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddleocr/_pipelines/ocr.py:163, in PaddleOCR.__init__(self, doc_orientation_classify_model_name, doc_orientation_classify_model_dir, doc_unwarping_model_name, doc_unwarping_model_dir, text_detection_model_name, text_detection_model_dir, textline_orientation_model_name, textline_orientation_model_dir, textline_orientation_batch_size, text_recognition_model_name, text_recognition_model_dir, text_recognition_batch_size, use_doc_orientation_classify, use_doc_unwarping, use_textline_orientation, text_det_limit_side_len, text_det_limit_type, text_det_thresh, text_det_box_thresh, text_det_unclip_ratio, text_det_input_shape, text_rec_score_thresh, return_word_box, text_rec_input_shape, lang, ocr_version, **kwargs)
#     159         base_params[name] = val
#     161 self._params = params
# --> 163 super().__init__(**base_params)
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddleocr/_pipelines/base.py:67, in PaddleXPipelineWrapper.__init__(self, paddlex_config, **common_args)
#      63 self._common_args = parse_common_args(
#      64     common_args, default_enable_hpi=_DEFAULT_ENABLE_HPI
#      65 )
#      66 self._merged_paddlex_config = self._get_merged_paddlex_config()
# ---> 67 self.paddlex_pipeline = self._create_paddlex_pipeline()
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddleocr/_pipelines/base.py:105, in PaddleXPipelineWrapper._create_paddlex_pipeline(self)
#     103 kwargs = prepare_common_init_args(None, self._common_args)
#     104 try:
# --> 105     return create_pipeline(config=self._merged_paddlex_config, **kwargs)
#     106 except DependencyError as e:
#     107     raise RuntimeError(
#     108         "A dependency error occurred during pipeline creation. Please refer to the installation documentation to ensure all required dependencies are installed."
#     109     ) from e
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddlex/inference/pipelines/__init__.py:167, in create_pipeline(pipeline, config, device, pp_option, use_hpip, hpi_config, *args, **kwargs)
#     164 else:
#     165     config.pop("hpi_config", None)
# --> 167 pipeline = BasePipeline.get(pipeline_name)(
#     168     config=config,
#     169     device=device,
#     170     pp_option=pp_option,
#     171     use_hpip=use_hpip,
#     172     hpi_config=hpi_config,
#     173     *args,
#     174     **kwargs,
#     175 )
#     176 return pipeline
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddlex/utils/deps.py:206, in pipeline_requires_extra.<locals>._deco.<locals>._wrapper(self, *args, **kwargs)
#     203 @wraps(pipeline_cls.__init__)
#     204 def _wrapper(self, *args, **kwargs):
#     205     require_extra(extra, obj_name=pipeline_name, alt=alt)
# --> 206     return old_init_func(self, *args, **kwargs)
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddlex/inference/pipelines/_parallel.py:103, in AutoParallelSimpleInferencePipeline.__init__(self, config, *args, **kwargs)
#      97         self._executor = MultiDeviceSimpleInferenceExecutor(
#      98             self._pipelines,
#      99             batch_sampler,
#     100             postprocess_result=self._postprocess_result,
#     101         )
#     102 if not self._multi_device_inference:
# --> 103     self._pipeline = self._create_internal_pipeline(config, self.device)
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddlex/inference/pipelines/_parallel.py:158, in AutoParallelImageSimpleInferencePipeline._create_internal_pipeline(self, config, device)
#     157 def _create_internal_pipeline(self, config, device):
# --> 158     return self._pipeline_cls(
#     159         config,
#     160         device=device,
#     161         pp_option=self.pp_option,
#     162         use_hpip=self.use_hpip,
#     163         hpi_config=self.hpi_config,
#     164     )
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddlex/inference/pipelines/ocr/pipeline.py:117, in _OCRPipeline.__init__(self, config, device, pp_option, use_hpip, hpi_config)
#     114 else:
#     115     raise ValueError("Unsupported text type {}".format(self.text_type))
# --> 117 self.text_det_model = self.create_model(
#     118     text_det_config,
#     119     limit_side_len=self.text_det_limit_side_len,
#     120     limit_type=self.text_det_limit_type,
#     121     max_side_limit=self.text_det_max_side_limit,
#     122     thresh=self.text_det_thresh,
#     123     box_thresh=self.text_det_box_thresh,
#     124     unclip_ratio=self.text_det_unclip_ratio,
#     125     input_shape=self.input_shape,
#     126 )
#     128 text_rec_config = config.get("SubModules", {}).get(
#     129     "TextRecognition",
#     130     {"model_config_error": "config error for text_rec_model!"},
#     131 )
#     132 self.text_rec_score_thresh = text_rec_config.get("score_thresh", 0)
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddlex/inference/pipelines/base.py:106, in BasePipeline.create_model(self, config, **kwargs)
#     103 else:
#     104     pp_option = None
# --> 106 model = create_predictor(
#     107     model_name=config["model_name"],
#     108     model_dir=model_dir,
#     109     device=self.device,
#     110     batch_size=config.get("batch_size", 1),
#     111     pp_option=pp_option,
#     112     use_hpip=use_hpip,
#     113     hpi_config=hpi_config,
#     114     genai_config=genai_config,
#     115     **kwargs,
#     116 )
#     117 return model
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddlex/inference/models/__init__.py:80, in create_predictor(model_name, model_dir, device, pp_option, use_hpip, hpi_config, genai_config, *args, **kwargs)
#      78         assert Path(model_dir).exists(), f"{model_dir} is not exists!"
#      79         model_dir = Path(model_dir)
# ---> 80     config = BasePredictor.load_config(model_dir)
#      81     assert (
#      82         model_name == config["Global"]["model_name"]
#      83     ), f"Model name mismatch，please input the correct model dir."
#      84 else:
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddlex/inference/models/base/predictor/base_predictor.py:374, in BasePredictor.load_config(cls, model_dir)
#     365 """Load the configuration from the specified model directory.
#     366
#     367 Args:
#    (...)
#     371     dict: The loaded configuration dictionary.
#     372 """
#     373 yaml_reader = YAMLReader()
# --> 374 return yaml_reader.read(cls.get_config_path(model_dir))
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddlex/inference/utils/io/readers.py:199, in YAMLReader.read(self, in_path)
#     198 def read(self, in_path):
# --> 199     return self._backend.read_file(str(in_path))
#
# File ~/github/kor-it-langchain-class/paddle/.venv/lib/python3.10/site-packages/paddlex/inference/utils/io/readers.py:517, in YAMLReaderBackend.read_file(self, in_path, **kwargs)
#     516 def read_file(self, in_path, **kwargs):
# --> 517     with open(in_path, "r", encoding="utf-8", **kwargs) as yaml_file:
#     518         data = yaml.load(yaml_file, Loader=yaml.FullLoader)
#     519     return data
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/dandy/.paddlex/official_models/PP-OCRv5_server_det/inference.yml'

# %%
# Visualize the results and save the JSON results
for res in result:
    res.print()
    res.save_to_img("output")
    res.save_to_json("output")

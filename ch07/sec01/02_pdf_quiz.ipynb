# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.document_loaders import PyMuPDFLoader

# 문서 로드
loader = PyMuPDFLoader('../data/2026_수능특강_문학_slice.pdf')
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20250821193224', 'source': '../data/2026_수능특강_문학_slice.pdf', 'file_path': '../data/2026_수능특강_문학_slice.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20250821193224', 'page': 0}, page_content='1 Úᬒ‷wⲒ⸺\n(1) 시적 표현의 개념\n• 시의 주제나 화자의 정서를 형상화하는 데 기여하는 일체의 언어적 표현을 가리킴.\n• 비유, 상징, 역설, 반어, 대구, 반복, 설의, 영탄, 도치, 열거, 점층, 우의, 풍자, 병렬 등\n의 표현 기법이 있음.\n(2) 시적 표현의 여러 가지 효과\n•음악적인 리듬이 느껴지게 함.\n•시어의 함축성을 높여 의미를 풍부하게 함.\n•어떤 대상을 감각적으로 연상하게 함.\n•상식적인 생각을 뒤집거나 깨뜨림으로써 지적 충격을 줌.\n•재미를 느끼고 웃게 하거나 반대로 슬픈 감정을 환기하게 함.\n•일상적인 표현에 변화를 가하여 말의 묘미를 느끼게 함.\n•화자의 사고나 감정, 상황 등을 강조하거나 부각함.\n 형상화\n정서나 교훈, 삶의 이치 등과 같\n이 분명한 형체로 나타나 있지 \n않은 것을 다양한 방법이나 매체\n를 통해 구체적이고 실감 나게 \n그려 내는 것을 뜻한다. 문학에\n서는 마음이나 윤리적 덕목과 같\n은 추상적인 대상도 구체적인 형\n상으로 드러난다.\n2 Úᬒᾎw⹋ᬓ\n(1) 시의 형식의 개념과 특성\n• 율격, 시행, 연 등의 요소가 시의 주제나 화자의 정서를 표현하면서 이루는 전체적인 형\n태나 구조를 가리킴. 크게 고정된 형식과 자유로운 형식으로 구별됨.\n•시의 형식은 문화적으로 형성된 시 고유의 체계와 관습에 기반을 두고 있음.    \n(2) 시의 형식의 여러 층위\n•갈래: 민요, 시조, 가사, 자유시 등\n•담화 양식: 독백, 대화, 편지, 전화 통화의 형식 등\n•구조: 기승전결, 수미상관, 선경후정, 대칭, 아이러니(반어) 등\n•진술 형태: 정형시, 자유시, 산문시, 이야기시, 극시 등\n•형태: 시행 및 연의 배열 등\n•청자의 존재: 독백, 대화 등   \n•시상 전개: 원경- 근경, 외부 풍경-내면세계, 과거-현재-미래 등\n 표현과 형식의 관계\n시적 표현이라는 말의 의미는 그 \n폭이 매우 넓어서 형식의 의미를 \n포괄하는 경우가 많다. 그러므로 \n표현과 형식을 별도의 개념으로 \n인식하기보다는 형식을 표현의 \n한 부분으로 이해하는 것이 바람\n직하다.\n 독백과 대화\n독백은 화자가 자신을 청자로 삼\n아 하는 말이고, 대화는 청자를 \n향해서 하는 말이다. 따라서 상대\n방을 상정하고 하는 질문, 명령, \n부탁, 위로, 격려 등의 말은 형식\n적으로 대화에 해당한다. ‘~입니\n다’ 등의 높임말도 자신에게 하\n는 말이 아니라는 점에서 표면적\n으로는 대화 형식에 해당한다.\nᬒᾎwⲒ⸺Բw⹋ᬓ\n1\n008  EBS 수능특강 국어영역 문학')]

# %%
print(docs[0].page_content)
# Out:
# 1 Úᬒ‷wⲒ⸺
# (1) 시적 표현의 개념
# • 시의 주제나 화자의 정서를 형상화하는 데 기여하는 일체의 언어적 표현을 가리킴.
# • 비유, 상징, 역설, 반어, 대구, 반복, 설의, 영탄, 도치, 열거, 점층, 우의, 풍자, 병렬 등
# 의 표현 기법이 있음.
# (2) 시적 표현의 여러 가지 효과
# •음악적인 리듬이 느껴지게 함.
# •시어의 함축성을 높여 의미를 풍부하게 함.
# •어떤 대상을 감각적으로 연상하게 함.
# •상식적인 생각을 뒤집거나 깨뜨림으로써 지적 충격을 줌.
# •재미를 느끼고 웃게 하거나 반대로 슬픈 감정을 환기하게 함.
# •일상적인 표현에 변화를 가하여 말의 묘미를 느끼게 함.
# •화자의 사고나 감정, 상황 등을 강조하거나 부각함.
#  형상화
# 정서나 교훈, 삶의 이치 등과 같
# 이 분명한 형체로 나타나 있지
# 않은 것을 다양한 방법이나 매체
# 를 통해 구체적이고 실감 나게
# 그려 내는 것을 뜻한다. 문학에
# 서는 마음이나 윤리적 덕목과 같
# 은 추상적인 대상도 구체적인 형
# 상으로 드러난다.
# 2 Úᬒᾎw⹋ᬓ
# (1) 시의 형식의 개념과 특성
# • 율격, 시행, 연 등의 요소가 시의 주제나 화자의 정서를 표현하면서 이루는 전체적인 형
# 태나 구조를 가리킴. 크게 고정된 형식과 자유로운 형식으로 구별됨.
# •시의 형식은 문화적으로 형성된 시 고유의 체계와 관습에 기반을 두고 있음.
# (2) 시의 형식의 여러 층위
# •갈래: 민요, 시조, 가사, 자유시 등
# •담화 양식: 독백, 대화, 편지, 전화 통화의 형식 등
# •구조: 기승전결, 수미상관, 선경후정, 대칭, 아이러니(반어) 등
# •진술 형태: 정형시, 자유시, 산문시, 이야기시, 극시 등
# •형태: 시행 및 연의 배열 등
# •청자의 존재: 독백, 대화 등
# •시상 전개: 원경- 근경, 외부 풍경-내면세계, 과거-현재-미래 등
#  표현과 형식의 관계
# 시적 표현이라는 말의 의미는 그
# 폭이 매우 넓어서 형식의 의미를
# 포괄하는 경우가 많다. 그러므로
# 표현과 형식을 별도의 개념으로
# 인식하기보다는 형식을 표현의
# 한 부분으로 이해하는 것이 바람
# 직하다.
#  독백과 대화
# 독백은 화자가 자신을 청자로 삼
# 아 하는 말이고, 대화는 청자를
# 향해서 하는 말이다. 따라서 상대
# 방을 상정하고 하는 질문, 명령,
# 부탁, 위로, 격려 등의 말은 형식
# 적으로 대화에 해당한다. ‘~입니
# 다’ 등의 높임말도 자신에게 하
# 는 말이 아니라는 점에서 표면적
# 으로는 대화 형식에 해당한다.
# ᬒᾎwⲒ⸺Բw⹋ᬓ
# 1
# 008  EBS 수능특강 국어영역 문학

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate

model = init_chat_model(
    "google_genai:gemini-3-flash-preview",
)

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """당신은 제공된 텍스트에서 의미 있고 맥락적으로 관련된 질문을 생성하도록 설계된 고급 질문 생성기입니다.
            주어진 텍스트를 사용하여 한국어로 사고를 자극하거나 이해력 기반의 질문을 생성하세요.
            답변은 포함하지 마세요.
            \n\n
            {context}""",
        ),
        (
            "human",
            "{input}"
        )
    ]
)

chain = prompt | model

# %%
pdf_context = ''
for doc in docs:
    print(doc)
    pdf_context += doc.page_content
# Out:
# page_content='1 Úᬒ‷wⲒ⸺
# (1) 시적 표현의 개념
# • 시의 주제나 화자의 정서를 형상화하는 데 기여하는 일체의 언어적 표현을 가리킴.
# • 비유, 상징, 역설, 반어, 대구, 반복, 설의, 영탄, 도치, 열거, 점층, 우의, 풍자, 병렬 등
# 의 표현 기법이 있음.
# (2) 시적 표현의 여러 가지 효과
# •음악적인 리듬이 느껴지게 함.
# •시어의 함축성을 높여 의미를 풍부하게 함.
# •어떤 대상을 감각적으로 연상하게 함.
# •상식적인 생각을 뒤집거나 깨뜨림으로써 지적 충격을 줌.
# •재미를 느끼고 웃게 하거나 반대로 슬픈 감정을 환기하게 함.
# •일상적인 표현에 변화를 가하여 말의 묘미를 느끼게 함.
# •화자의 사고나 감정, 상황 등을 강조하거나 부각함.
#  형상화
# 정서나 교훈, 삶의 이치 등과 같
# 이 분명한 형체로 나타나 있지
# 않은 것을 다양한 방법이나 매체
# 를 통해 구체적이고 실감 나게
# 그려 내는 것을 뜻한다. 문학에
# 서는 마음이나 윤리적 덕목과 같
# 은 추상적인 대상도 구체적인 형
# 상으로 드러난다.
# 2 Úᬒᾎw⹋ᬓ
# (1) 시의 형식의 개념과 특성
# • 율격, 시행, 연 등의 요소가 시의 주제나 화자의 정서를 표현하면서 이루는 전체적인 형
# 태나 구조를 가리킴. 크게 고정된 형식과 자유로운 형식으로 구별됨.
# •시의 형식은 문화적으로 형성된 시 고유의 체계와 관습에 기반을 두고 있음.
# (2) 시의 형식의 여러 층위
# •갈래: 민요, 시조, 가사, 자유시 등
# •담화 양식: 독백, 대화, 편지, 전화 통화의 형식 등
# •구조: 기승전결, 수미상관, 선경후정, 대칭, 아이러니(반어) 등
# •진술 형태: 정형시, 자유시, 산문시, 이야기시, 극시 등
# •형태: 시행 및 연의 배열 등
# •청자의 존재: 독백, 대화 등
# •시상 전개: 원경- 근경, 외부 풍경-내면세계, 과거-현재-미래 등
#  표현과 형식의 관계
# 시적 표현이라는 말의 의미는 그
# 폭이 매우 넓어서 형식의 의미를
# 포괄하는 경우가 많다. 그러므로
# 표현과 형식을 별도의 개념으로
# 인식하기보다는 형식을 표현의
# 한 부분으로 이해하는 것이 바람
# 직하다.
#  독백과 대화
# 독백은 화자가 자신을 청자로 삼
# 아 하는 말이고, 대화는 청자를
# 향해서 하는 말이다. 따라서 상대
# 방을 상정하고 하는 질문, 명령,
# 부탁, 위로, 격려 등의 말은 형식
# 적으로 대화에 해당한다. ‘~입니
# 다’ 등의 높임말도 자신에게 하
# 는 말이 아니라는 점에서 표면적
# 으로는 대화 형식에 해당한다.
# ᬒᾎwⲒ⸺Բw⹋ᬓ
# 1
# 008  EBS 수능특강 국어영역 문학' metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20250821193224', 'source': '../data/2026_수능특강_문학_slice.pdf', 'file_path': '../data/2026_수능특강_문학_slice.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20250821193224', 'page': 0}

# %%
type(pdf_context)
# Out:
# str

# %%
response = chain.invoke({
    "context": pdf_context, "input": "4지선다 3문항을 만들어 주세요."
})
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 response = chain.invoke({
#       2     "context": pdf_context, "input": "4지선다 3문항을 만들어 주세요."
#       3 })
#       4 print(response.content)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\langchain_core\runnables\base.py:3129, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3127                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3128             else:
# -> 3129                 input_ = context.run(step.invoke, input_, config)
#    3130 # finish the root run
#    3131 except BaseException as e:
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2119, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2116         msg = "Tools are already defined.code_execution tool can't be defined"
#    2117         raise ValueError(msg)
# -> 2119 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:385, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     371 @override
#     372 def invoke(
#     373     self,
#    (...)    378     **kwargs: Any,
#     379 ) -> AIMessage:
#     380     config = ensure_config(config)
#     381     return cast(
#     382         "AIMessage",
#     383         cast(
#     384             "ChatGeneration",
# --> 385             self.generate_prompt(
#     386                 [self._convert_input(input)],
#     387                 stop=stop,
#     388                 callbacks=config.get("callbacks"),
#     389                 tags=config.get("tags"),
#     390                 metadata=config.get("metadata"),
#     391                 run_name=config.get("run_name"),
#     392                 run_id=config.pop("run_id", None),
#     393                 **kwargs,
#     394             ).generations[0][0],
#     395         ).message,
#     396     )
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1104, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1095 @override
#    1096 def generate_prompt(
#    1097     self,
#    (...)   1101     **kwargs: Any,
#    1102 ) -> LLMResult:
#    1103     prompt_messages = [p.to_messages() for p in prompts]
# -> 1104     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:914, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     911 for i, m in enumerate(input_messages):
#     912     try:
#     913         results.append(
# --> 914             self._generate_with_cache(
#     915                 m,
#     916                 stop=stop,
#     917                 run_manager=run_managers[i] if run_managers else None,
#     918                 **kwargs,
#     919             )
#     920         )
#     921     except BaseException as e:
#     922         if run_managers:
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1208, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1206     result = generate_from_stream(iter(chunks))
#    1207 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1208     result = self._generate(
#    1209         messages, stop=stop, run_manager=run_manager, **kwargs
#    1210     )
#    1211 else:
#    1212     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2270, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    2268 if "max_retries" not in kwargs:
#    2269     kwargs["max_retries"] = self.max_retries
# -> 2270 response: GenerateContentResponse = _chat_with_retry(
#    2271     request=request,
#    2272     **kwargs,
#    2273     generation_method=self.client.generate_content,
#    2274     metadata=self.default_metadata,
#    2275 )
#    2276 return _response_to_result(response)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:258, in _chat_with_retry(generation_method, **kwargs)
#     253         raise
#     255 params = {
#     256     k: v for k, v in kwargs.items() if k in _allowed_params_prediction_service
#     257 }
# --> 258 return _chat_with_retry(**params)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\tenacity\__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\tenacity\__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.11-windows-x86_64-none\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.11-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:232, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     229 @retry_decorator
#     230 def _chat_with_retry(**kwargs: Any) -> Any:
#     231     try:
# --> 232         return generation_method(**kwargs)
#     233     except FailedPrecondition as exc:
#     234         if "location is not supported" in exc.message:
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:869, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     866 self._validate_universe_domain()
#     868 # Send the request.
# --> 869 response = rpc(
#     870     request,
#     871     retry=retry,
#     872     timeout=timeout,
#     873     metadata=metadata,
#     874 )
#     876 # Done; return the response.
#     877 return response
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\google\api_core\grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
#     281         wait_for_ready=wait_for_ready,
#     282         compression=compression,
#     283     )
#     284     return response
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\grpc\_interceptor.py:328, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     325     except Exception as exception:  # pylint:disable=broad-except
#     326         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 328 call = self._interceptor.intercept_unary_unary(
#     329     continuation, client_call_details, request
#     330 )
#     331 return call.result(), call
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\transports\grpc.py:78, in _LoggingClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      64     grpc_request = {
#      65         "payload": request_payload,
#      66         "requestMethod": "grpc",
#      67         "metadata": dict(request_metadata),
#      68     }
#      69     _LOGGER.debug(
#      70         f"Sending request for {client_call_details.method}",
#      71         extra={
#    (...)     76         },
#      77     )
# ---> 78 response = continuation(client_call_details, request)
#      79 if logging_enabled:  # pragma: NO COVER
#      80     response_metadata = response.trailing_metadata()
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\grpc\_interceptor.py:314, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     305 (
#     306     new_method,
#     307     new_timeout,
#    (...)    311     new_compression,
#     312 ) = _unwrap_client_call_details(new_details, client_call_details)
#     313 try:
# --> 314     response, call = self._thunk(new_method).with_call(
#     315         request,
#     316         timeout=new_timeout,
#     317         metadata=new_metadata,
#     318         credentials=new_credentials,
#     319         wait_for_ready=new_wait_for_ready,
#     320         compression=new_compression,
#     321     )
#     322     return _UnaryOutcome(response, call)
#     323 except grpc.RpcError as rpc_error:
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\grpc\_channel.py:1177, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1168 def with_call(
#    1169     self,
#    1170     request: Any,
#    (...)   1175     compression: Optional[grpc.Compression] = None,
#    1176 ) -> Tuple[Any, grpc.Call]:
# -> 1177     state, call = self._blocking(
#    1178         request, timeout, metadata, credentials, wait_for_ready, compression
#    1179     )
#    1180     return _end_unary_response_blocking(state, call, True, None)
#
# File c:\Users\dandycode\Documents\GitHub\kor-it-langchain-class\ch07\.venv\Lib\site-packages\grpc\_channel.py:1150, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1133 state.target = _common.decode(self._target)
#    1134 call = self._channel.segregated_call(
#    1135     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1136     self._method,
#    (...)   1148     self._registered_call_handle,
#    1149 )
# -> 1150 event = call.next_event()
#    1151 _handle_event(event, state, self._response_deserializer)
#    1152 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:97, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:80, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %%
response = chain.invoke({
    "context": pdf_context, "input": "주관식 2문항을 만들어 주세요."
})
print(response.content)
# Out:
# 다음은 제공된 텍스트를 바탕으로 생성된 주관식 질문 2문항입니다.
#
# 1.  제시된 텍스트에서는 "표현과 형식을 별도의 개념으로 인식하기보다는 형식을 표현의 한 부분으로 이해하는 것이 바람직하다"고 설명합니다. '시적 표현'의 개념과 '시의 형식'의 개념 및 특성을 종합하여 이러한 관점이 제시된 이유를 설명하시오.
# 2.  시는 '형상화'를 통해 정서나 교훈 등을 구체적이고 실감 나게 그려냅니다. 이 목표를 달성하기 위해 '시적 표현의 여러 가지 효과' 중 두 가지와 '시의 형식의 여러 층위' 중 두 가지를 선택하여, 각각이 시의 형상화에 어떻게 기여할 수 있는지 구체적인 방식으로 설명하시오.

# %% [markdown]
# > 공식 문서: <https://langchain-ai.github.io/langgraph/tutorials/multi_agent/agent_supervisor/#research-agent>

# %% [markdown]
# ### 1. Create worker agents

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.tools import tool
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper
from langchain_community.tools import DuckDuckGoSearchResults 

@tool
def get_web_search(query: str, search_period: str='w') -> str:
    """
    웹 검색을 수행하는 함수.

    Args:
        query (str): 검색어
        search_period (str): 검색 기간 (e.g., "w" for past week (default), "m" for past month, "y" for past year, "d" for past day)

    Returns:
        str: 검색 결과
    """
    wrapper = DuckDuckGoSearchAPIWrapper(
        time=search_period
    )

    print('\n----- WEB SEARCH -----')
    print(query)
    print(search_period)

    search = DuckDuckGoSearchResults(
        api_wrapper=wrapper,
        results_separator=';\n'
    )

    searched = search.invoke(query)
    
    for i, result in enumerate(searched.split(';\n')):
        print(f'{i+1}. {result}')
    
    return searched

# %%
from langgraph.prebuilt import create_react_agent

research_agent = create_react_agent(
    model="google_genai:gemini-3.1-flash-lite",
    tools=[get_web_search],
    prompt=(
        "당신은 리서치 에이전트입니다.\n\n"
        "지시사항:\n"
        "- 리서치 관련 작업만 수행하고, 수학 계산은 절대 하지 마세요.\n"
        "- 작업을 완료한 후에는 감독관(supervisor)에게 직접 응답하세요.\n"
        "- 작업 결과만 응답하고, 다른 텍스트는 포함하지 마세요."
    ),
    name="research_agent",
)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_8432\2853663219.py:3: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   research_agent = create_react_agent(

# %%
from langchain_core.messages import convert_to_messages


def pretty_print_message(message, indent=False):
    pretty_message = message.pretty_repr(html=True)
    if not indent:
        print(pretty_message)
        return

    indented = "\n".join("\t" + c for c in pretty_message.split("\n"))
    print(indented)


def pretty_print_messages(update, last_message=False):
    is_subgraph = False
    if isinstance(update, tuple):
        ns, update = update
        # skip parent graph updates in the printouts
        if len(ns) == 0:
            return

        graph_id = ns[-1].split(":")[0]
        print(f"Update from subgraph {graph_id}:")
        print("\n")
        is_subgraph = True

    for node_name, node_update in update.items():
        update_label = f"Update from node {node_name}:"
        if is_subgraph:
            update_label = "\t" + update_label
        
        print(update_label)
        print("\n")

        messages = convert_to_messages(node_update["messages"])
        if last_message:
            messages = messages[-1:]

        for m in messages:
            pretty_print_message(m, indent=is_subgraph)
        print("\n")

# %%
for chunk in research_agent.stream(
    {"messages": [{"role": "user", "content": "부산시 시장은 누구일까?"}]}
):
    pretty_print_messages(chunk)
# Out:
# Update from node agent:
#
#
# ================================== Ai Message ==================================
# Name: research_agent
#
# []
# Tool Calls:
#   get_web_search (1c64e625-f314-4ca4-a151-ef84e75b285b)
#  Call ID: 1c64e625-f314-4ca4-a151-ef84e75b285b
#   Args:
#     query: 부산광역시장
#
#
#
# ----- WEB SEARCH -----
# 부산광역시장
# w
# 1. snippet: 부산광역시체육회 (회장 장인화)는 지난 6월 11일 부산광역시장 당선인을 초청해 「민선9기 부산광역시장 당선인 초청 부산체육인 간담회」를 개최하고 부산체육 발전 방향과 주요 현안을 논의했다., title: 민선9기 부산광역시장 당선인 초청...부산체육인 간담회 개최 - 한국생활체육뉴스, link: http://www.kstnews.co.kr/news/articleView.html?idxno=41204
# 2. snippet: 이후 부산광역시청, 해운대구청 등에서 근무하다가 행정안전부 본부에서 지방세정책과장, 교부세과장 등 과장급 (3급) 직위를 거쳐 서병수 부산광역시장 당시 부산광역시청 정책기획실장 (고공단 나급, 2급)으로 근무하였다., title: 변성완 - 나무위키, link: https://namu.wiki/w/변성완
# 3. snippet: 3선 도전에 실패한 박형준 부산광역시장이 조기 퇴임한다. 11일 부산시에 따르면 오는 26일 오후 부산광역시청 대강당에서 직원들이 참석한 가운데 박 시장의 퇴임식을 연다. 박 시장의 공식 임기 종료일은 이달 30일이지만 일찌감치 퇴임식을 치른 뒤 남은 임기 동안 연가를 사용할 것으로 전해졌다., title: 박형준 부산시장, 26일 조기 퇴임…전재수 시정 준비 배려, link: https://www.inews24.com/view/1975787
# 4. snippet: 부산 시장 당선자 결과 안내 및 향후 시정 변화 총정리2026년 지방선거 부산 시장 당선자 최종 확정 및 투표 결과2026년 6월 3일에 실시된 제9회 전국동시지방선거에서 가장 뜨거운 관심을 모았던 부산광역시장 선거의 최종 승자가 가려졌습니다., title: 부산 시장 당선자 결과 안내 및 향후 시정 변화 총정리, link: https://muzicismylife.com/entry/부산-시장-당선자-결과-안내-및-향후-시정-변화-총정리
# Update from node tools:
#
#
# ================================= Tool Message =================================
# Name: get_web_search
#
# snippet: 부산광역시체육회 (회장 장인화)는 지난 6월 11일 부산광역시장 당선인을 초청해 「민선9기 부산광역시장 당선인 초청 부산체육인 간담회」를 개최하고 부산체육 발전 방향과 주요 현안을 논의했다., title: 민선9기 부산광역시장 당선인 초청...부산체육인 간담회 개최 - 한국생활체육뉴스, link: http://www.kstnews.co.kr/news/articleView.html?idxno=41204;
# snippet: 이후 부산광역시청, 해운대구청 등에서 근무하다가 행정안전부 본부에서 지방세정책과장, 교부세과장 등 과장급 (3급) 직위를 거쳐 서병수 부산광역시장 당시 부산광역시청 정책기획실장 (고공단 나급, 2급)으로 근무하였다., title: 변성완 - 나무위키, link: https://namu.wiki/w/변성완;
# snippet: 3선 도전에 실패한 박형준 부산광역시장이 조기 퇴임한다. 11일 부산시에 따르면 오는 26일 오후 부산광역시청 대강당에서 직원들이 참석한 가운데 박 시장의 퇴임식을 연다. 박 시장의 공식 임기 종료일은 이달 30일이지만 일찌감치 퇴임식을 치른 뒤 남은 임기 동안 연가를 사용할 것으로 전해졌다., title: 박형준 부산시장, 26일 조기 퇴임…전재수 시정 준비 배려, link: https://www.inews24.com/view/1975787;
# snippet: 부산 시장 당선자 결과 안내 및 향후 시정 변화 총정리2026년 지방선거 부산 시장 당선자 최종 확정 및 투표 결과2026년 6월 3일에 실시된 제9회 전국동시지방선거에서 가장 뜨거운 관심을 모았던 부산광역시장 선거의 최종 승자가 가려졌습니다., title: 부산 시장 당선자 결과 안내 및 향후 시정 변화 총정리, link: https://muzicismylife.com/entry/부산-시장-당선자-결과-안내-및-향후-시정-변화-총정리
#
#
# Update from node agent:
#
#
# ================================== Ai Message ==================================
# Name: research_agent
#
# [{'type': 'text', 'text': '감독관님, 현재 부산광역시장은 박형준입니다.', 'extras': {'signature': 'EjQKMgEMOdbHXRqnb4+Ukz7lTMlaRGbHHTmnSrMSiqS6TDXEla+vQAy6ODCFR7wIK4rsks2C'}}]

# %%
def add(a: float, b: float):
    """Add two numbers."""
    return a + b


def multiply(a: float, b: float):
    """Multiply two numbers."""
    return a * b


def divide(a: float, b: float):
    """Divide two numbers."""
    return a / b


math_agent = create_react_agent(
    model="google_genai:gemini-2.5-flash",
    tools=[add, multiply, divide],
    prompt=(
        "당신은 수학 에이전트입니다.\n\n"
        "지시사항:\n"
        "- 수학 관련 작업만 수행하세요.\n"
        "- 작업을 완료한 후에는 감독관(supervisor)에게 직접 응답하세요.\n"
        "- 작업 결과만 응답하고, 다른 텍스트는 포함하지 마세요."
    ),
    name="math_agent",
)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_8432\2013410382.py:16: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   math_agent = create_react_agent(

# %%
for chunk in math_agent.stream(
    {"messages": [{"role": "user", "content": "(3 + 5) x 7은 얼마인가요?"}]}
):
    pretty_print_messages(chunk)
# Out:
# Update from node agent:
#
#
# ================================== Ai Message ==================================
# Name: math_agent
# Tool Calls:
#   add (679b7cf4-e05d-4e3b-a8d5-03426c29f116)
#  Call ID: 679b7cf4-e05d-4e3b-a8d5-03426c29f116
#   Args:
#     a: 3
#     b: 5
#
#
# Update from node tools:
#
#
# ================================= Tool Message =================================
# Name: add
#
# 8.0
#
#
# Update from node agent:
#
#
# ================================== Ai Message ==================================
# Name: math_agent
# Tool Calls:
#   multiply (54223f66-32bb-4a1c-a3c5-d9d357aac753)
#  Call ID: 54223f66-32bb-4a1c-a3c5-d9d357aac753
#   Args:
#     a: 8
#     b: 7
#
#
# Update from node tools:
#
#
# ================================= Tool Message =================================
# Name: multiply
#
# 56.0
#
#
# Update from node agent:
#
#
# ================================== Ai Message ==================================
# Name: math_agent
#
# [{'type': 'text', 'text': '56', 'extras': {'signature': 'Cp4BAQw51sefgVjUjgGRLdqfRnSYimjoREbS5FlYH9yed/8qSenHp9KjzIUEd2kridom3tEWogLOKjC/mFT5K54/q44CO7LcVyuBfSLlhlfUOZKEoerh+OYBIsic4HjZgFeVd70pRmNJ7zdiqFyBHEWYFBXvUWFtotRQnmx74VyfLy187m3QMGigXRKNsSEMbIdFxwSwt+0ZPSXrAPLJwq8='}}]

# %% [markdown]
# ### 2. Create supervisor with langgraph-supervisor

# %%
from langgraph_supervisor import create_supervisor # uv add langgraph-supervisor
from langchain.chat_models import init_chat_model

supervisor = create_supervisor(
    model=init_chat_model("google_genai:gemini-3.1-flash-lite"),
    agents=[research_agent, math_agent],
    prompt=(
        "당신은 두 에이전트를 관리하는 감독관입니다:\n"
        "- 리서치 에이전트. 리서치 관련 작업은 이 에이전트에게 할당하세요.\n"
        "- 수학 에이전트. 수학 관련 작업은 이 에이전트에게 할당하세요.\n"
        "한 번에 하나의 에이전트에게만 작업을 할당하고, 여러 에이전트를 병렬로 호출하지 마세요.\n"
        "어떤 작업도 직접 수행하지 마세요."
    ),
    add_handoff_back_messages=True,
    output_mode="full_history",
).compile()

# %%
from IPython.display import display, Image

Image(supervisor.get_graph().draw_mermaid_png())

# %%
for chunk in supervisor.stream(
    {
        "messages": [
            {
                "role": "user",
                "content": "2025년 한국과 부산시의 GDP를 찾으세요. 부산시는 한국 GDP의 몇 퍼센트인가요?",
            }
        ]
    },
):
    pretty_print_messages(chunk, last_message=True)

final_message_history = chunk["supervisor"]["messages"]
# Out:
# Update from node supervisor:
#
#
# ================================= Tool Message =================================
# Name: transfer_to_research_agent
#
# Successfully transferred to research_agent
#
#
#
# ----- WEB SEARCH -----
# 2025년 한국 GDP 전망치
# w
# 1. snippet: 3 days ago · 이날 한국은행은 올해 1분기 명목 GDP 성장률이 작년 동기대비 17.1%로 1995년 3분기 (19.2%) 이후 30년 6개월 만에 최고였다고 밝혔다., title: 씨티, 올해 명목 GDP 성장률 10.6→15.3%로 전망치 상향, link: https://www.msn.com/ko-kr/money/경제/씨티-올해-명목-gdp-성장률-10-6-15-3-로-전망치-상향/ar-AA25a4Mq
# 2. snippet: 3 days ago · 한국씨티은행 김진욱 이코노미스트는 공개한 보고서를 통해 올해 명목 GDP 성장률을 기존 10.6%에서 이같이 상향 조정했는데, 이번 전망치는 1995년 이후 가장 높은 수준입니다. 반면 올해 실질 GDP 성장률 전망치는 기존과 같은 3.0%를 유지했습니다., title: 씨티, 올해 명목 GDP 성장률 10.6→15.3%로 전망치 상향 - SBS Biz, link: https://biz.sbs.co.kr/article/20000315460
# 3. snippet: 3 days ago · (서울=연합뉴스) 이도흔 기자 = 한국씨티은행은 한국의 올해 명목 국내총생산 (GDP) 성장률 전망치를 15.3%로 상향한다고 9일 밝혔다. 한국씨티은행 김진욱 이코노미스트는 이날 공개한 보고서를 통해 올해 명목 GDP 성장률을 기존 10.6%에서 이같이 상향 조정했다., title: 씨티, 올해 명목 GDP 성장률 10.6→15.3%로 전망치 상향, link: https://www.yna.co.kr/view/AKR20260609125400002
# 4. snippet: 3 days ago · 올해 1분기 실질 국내총생산 (GDP) 증가율이 1% 후반대로 확정된 데 이어 명목 GDP와 국민총소득 (GNI)은 수십 년 만에 가장 높은 증가폭을 기록했다. 한국은행은 이 같은 흐름이 이어질 경우 1인당 국민소득 4만달러 달성 시점도 앞당겨질 수 있다고 내다봤다., title: “이게 한국 경제 맞나”...명목 GDP 10.5%↑, 국민소득 ‘4만달러’ 눈앞, link: https://m.ekn.kr/view.php?key=20260609024471731
#
# ----- WEB SEARCH -----
# 부산시 지역내총생산 GRDP 비중
# w
# 1. snippet: 산업통상부 「2026년 지역전략산업 기반고도화 사업」 공모 선정 [국제언론인클럽=최수경기자] 부산시는 산업통상부 2026년 지역전략산업 기반고도화 사업 공모에 글로벌 시장대응 AI 기반 공조부품 성능평가 인프라 고도화 사업이 최종 선정됐다고 밝혔다., title: 부산시, 산업통상부 2026년 지역전략산업 기반고도화 사업 공모 선정, link: https://www.mimint.co.kr/bbs/view/news/S1N17/5421142
# 2. snippet: (부산=연합뉴스) 김선호 기자 = 부산시는 산업통상부의 2026년 지역전략산업 기반 고도화 사업 공모에 최종 선정됐다고 8일 밝혔다. 선정 분야는 '글로벌 시장대응 AI 기반 공조 부품 성능평가 인프라 고도화 사업'이다. 이 사업은 공조 부품과 청정공기 관련 제품의 성능을 신속하고 정밀하게 검증할 수 ..., title: 부산시, 지역전략산업 고도화 공모 선정…3년간 108억원 투입, link: https://stock.mk.co.kr/news/view/1100139
# 3. snippet: [부산=환경일보] 장가을 기자 = 부산시(시장 박형준)는 산업통상부 '2026년 지역전략산업 기반고도화 사업' 공모에 '글로벌 시장대응 AI 기반 공조부품 성능평가 인프라 고도화 사업'이 최종 선정됐다고 밝혔다.'글로벌 시장대응 AI 기반 공조부품 성능평가 인프라 고도화 사업'은 글로벌 환경 ..., title: 부산시, 산업통상부 '2026년 지역전략산업 기반고도화 사업' 공모 선정 < 보도자료 < 영남권 < 전국네트워크 < 기사본문 ..., link: https://www.hkbs.co.kr/news/articleView.html?idxno=824816
# 4. snippet: AI솔루션기반인프라고도화사업 부산시 (시장 박형준)는 산업통상부 2026년 지역전략산업 기반고도화 사업 공모에 '글로벌 시장대응 AI 기반 공조부품 성능평가 인프라 고도화 사업'이 최종 선정됐다고 밝혔다. 글로벌 시장대응 AI..., title: 부산시, 2026년 지역전략산업 기반고도화 사업 공모 선정, link: https://www.klan.kr/news/279764
#
# ----- WEB SEARCH -----
# 2023년 부산 GRDP 대한민국 GDP 비중
# w
# 1. snippet: Gross domestic product (GDP) is the market value of all final goods and services from a nation in a given year. [2] Countries are sorted by nominal GDP estimates from financial and statistical institutions, which are calculated at market or government official exchange rates. Nominal GDP does not take into account differences in the cost of living in different countries, and the results can ..., title: List of countries by GDP (nominal) - Wikipedia, link: https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)
# 2. snippet: Retrieved 30 May 2023. ^ The GDP data of prefecture-level cities in Fujian are from the statistical communiqué on 2020 national economic and social development published by the statistical agencies of prefecture-level cities, see 2020年福建各市GDP排名，福州、泉州双双破万亿，厦门暂居第三. sohu.com. 9 April 2021., title: List of cities by GDP - Wikipedia, link: https://en.wikipedia.org/wiki/List_of_cities_by_GDP
# 3. snippet: 四半期別GDP速報 2026年1-3月期・2次速報（2026年6月8日） 統計の概要 統計の目的 統計の沿革 統計の作成方法 統計の利活用事例 推計結果 用語の解説 結果の概要 利用上の注意 統計表一覧（最新の結果を掲載しています） 公表予定, title: 四半期別gdp速報 : 経済社会総合研究所 - 内閣府, link: https://www.esri.cao.go.jp/jp/sna/sokuhou/sokuhou_top.html
# 4. snippet: 2000-2023年各省名义GDP、实际GDP、GDP平减指数数据（含原始数据+计算过程+计算结果）（以2000年为基期） 1、时间：2000-2023年 2、范围：31省 3、指标：名义GDP、国内生产总值指数、实际GDP、GDP平减指数 4、来源：统计年鉴、国家统计局 5、缺失情况：无缺失 6、计算说明：以2000年为基期 第一步计算不 ..., title: 2000-2023年各省名义gdp、实际gdp、Gdp平减指数数据（含原始数据+计算过程+计算结果）（以2000年为基期）, link: http://www.lryc.cn/news/378763.html
#
# ----- WEB SEARCH -----
# 부산 GRDP 전국 비중 통계청
# w
# 1. snippet: 20시간 전 · 이른바 '재량적 소비' 업종 비중이 전국 3번째로 높아 물가 충격에 상대적으로 ... 부산 서비스업의 실질 GRDP 둔화 폭도 전국 평균보다 더 크게 나타났습니다., title: 동남지방통계청에 따르면 5월 기준 부산지역 고용률이 58.6%를 기록해 ..., link: https://www.instagram.com/reel/DZd9x27Nvac/
# 2. snippet: 2일 전 · 2015년 기준으로 부산의 3차 산업이 GRDP에서 차지하는 비중은 전국 시·도 단위에서 서울, 대전에 이은 3위다.[62] 다만 부산은 3차 산업 가운데 도·소매업, 숙박·음식점업 ..., title: 부산광역시 - 나무위키, link: https://namu.wiki/w/부산광역시
# 3. snippet: 16시간 전 · ✓ 지방 GRDP 1,209조 원(47.2%), 성장률 1.6% *지역내총생산(GRDP) 일정 기간 동안 일정 지역 내에서 발생한 부가가치 지역내총생산이 균형을 이룰 때, 각 지역의 잠재력이 ..., title: 대한민국 #국민주권정부_1년의_변화 #38대_대표성과_27 정부는 수도권 ..., link: https://www.instagram.com/p/DZeZ-kQnSps/
# 4. snippet: 4일 전 · 그리고 경상남도의 GRDP는 1997년까지 상승세를 지속하며 최고 약 61조 원을 기록하였는데, 울산이 떨어져 나간 이후 1998년의 GRDP가 약 36조 원으로 거의 반토막났다., title: 광역시 - 나무위키, link: https://namu.wiki/w/광역시
#
# ----- WEB SEARCH -----
# "부산" GRDP 전국 비중 "퍼센트"
# w
# 1. snippet: 퍼센트 peosenteu n.b. percent • 내가 보기에는 백 퍼센트 거짓말이야. — In my opinion, it is one hundred percent a lie.비중 bijung n. importance; specific gravity • 배우는 영화에서 비중이 있는 역할을 맡았다. — The actor took an important role in the movie., title: A-Frequency-Dictionary-of-Korean.pdf - PDFCOFFEE.COM, link: https://pdfcoffee.com/a-frequency-dictionary-of-koreanpdf-pdf-free.html
# 2. snippet: 주요 내용으로는 일반지역은 10퍼센트, 인구감소지역은 최대 20퍼센트까지 산지전용허가기준을 완화할 수 있도록 하고, 허가기준의 적정성과 실효성을 확보하기 위한 주., title: 경남도의회, 산지전용허가기준 조례안 심사보류…추가 검토 필요성 제기, link: https://www.gukjenews.com/news/articleView.html?idxno=3606837
# 3. snippet: #삼성페이X롯데월드 이벤트 공유하고 #나이트파티 가자! 9월 한달 간 #롯데월드 에서 #삼성페이 결제 시, 자유이용권 최대 60퍼센트 할인 혜택을! http://bit.ly/2clD5zo https://cards.twitter.com/cards/18ce54ahcva/27qj1…, title: 맘무덥 (@mammoodeop) / Twitter, link: https://twitter.com/mammoodeop
# 4. snippet: 부산 당일치기 어땠냐면요... 더보기. Download. @symmetric.percent 彡시메트릭 퍼센트 한남 스토어 오픈彡 옷 전부 편하게 몸에 착 붙어요 착용감 최고•• 컬러도 너무 예 브다 25Fw보러가세요%% #시메트릭퍼센트 #한남동쇼룸. 0., title: (@_urndbdry) Instagram profile, stories - Pixnoy (formerly Pixwox), link: https://www.pixnoy.com/profile/_urndbdry/
#
# ----- WEB SEARCH -----
# 2022년 부산 GRDP 비중 전국 GDP
# w
# 1. snippet: Countries by nominal GDP projected for 2025: [n 2] Gross domestic product (GDP) is the market value of all final goods and services from a nation in a given year. [2] Countries are sorted by nominal GDP estimates from financial and statistical institutions, which are calculated at market or government official exchange rates. Nominal GDP does not take into account differences in the cost of ..., title: List of countries by GDP (nominal) - Wikipedia, link: https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)
# 2. snippet: Selection of GDP (PPP) data (top 10 countries and blocs) in no particular order GDP (PPP) means gross domestic product based on purchasing power parity. This article includes a list of countries by their forecast estimated GDP (PPP). [1] Countries are sorted by GDP (PPP) forecast estimates from financial and statistical institutions that calculate using market or government official exchange ..., title: List of countries by GDP (PPP) - Wikipedia, link: https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(PPP)
# 3. snippet: 2022年世界各国GDP数据 GDP是国内生产总值, Gross Domestic Product的缩写。 它指一个国家或地区在一定时期内生产活动 (最终产品和服务)的总量,是衡量经济规模和发展水平最重要的方法之一。, title: 2022年世界各国gdp数据 -- 快易数据, link: https://www.kylc.com/stats/global/yearly/g_gdp/2022.html
# 4. snippet: 1분기 명목 GDP 성장률은 전 분기 대비 10.5%에 달해 1976년 1분기 (13.0%) 이후 50년 만에 최고치를 기록했다. 전년 동기와 비교하면 17.1% 성장해 1995년 3분기 (19.2%) 이후 30년6개월 만에 최고였다. 1분기 명목 GDP 성장률 상승은 국내 물가 상승이 아닌 수출 기업 수익성이 ..., title: 1분기 Gdp 성장률 1.8%로 더 올라…명목 Gdp 50년 만에 최고 - 시사저널, link: https://www.sisajournal.com/news/articleView.html?idxno=375844
#
# ----- WEB SEARCH -----
# 부산 지역내총생산 비중 전국 대비
# w
# 1. snippet: 부산·인천 지역내총생산 추이 [국가데이터처].부산, AI로 극한 호우 대비… 국책연구원 4곳과 협약., title: 부산 지역내총생산 인천에 또 밀렸다…격차 4조원까지 벌어져 - 매일경제, link: https://www.mk.co.kr/news/society/11505785
# 2. snippet: 작년 지역내총생산 '수도권' 비중 절반…소득도 쏠림 현상. 지난해 전국 지역내총생산 성장률은 전년 대비 2.0% 증가했다., title: 작년 지역내총생산 53% '수도권' 집중…성장·투자 격차 벌어져 | 뉴스핌, link: https://www.newspim.com/news/view/20251223000457
# 3. snippet: #지역내총생산 #최하위 #부산 #경제(2025-12-26,금/뉴스데스크/부산MBC)기사 내용 https://busanmbc.co.kr/01_new/new01_view.asp?idx=281406#부산시 #부산뉴스 #엠비씨뉴스 #mbc뉴스 #부산MBC #부산문화방송 #부산엠비씨 #부산엠비씨뉴스 #부산mbc뉴스..., title: 부산 1인당 지역내총생산 전국 최하위권, link: https://www.msn.com/ko-kr/money/경제/부산-1인당-지역내총생산-전국-최하위권/vi-AA1T6sFZ
# 4. snippet: 부산 남구 신선대 부두 야적장. [부산=뉴시스] 하경민 기자 = 부산·울산·경남 등 동남권의 지역내총생산이 수도권의 4분의 1 수준으로 나타났다., title: 동남권 지역내총생산, 수도권 대비 4분의 1…실질성장률 -5.2%, link: https://www.fnnews.com/news/202211161353300374
#
# ----- WEB SEARCH -----
# 부산 GRDP 전국 비중 퍼센트
# w
# 1. snippet: Busan (Korean: 부산; Hanja: 釜山; pronounced [pusʰan]), officially Busan Metropolitan City, is the second most populous city in South Korea, after Seoul; it has a population of over 3.3 million as of 2024.[5] Alternatively romanized as Pusan, it is the e..., title: Busan - Wikipedia, link: https://en.wikipedia.org/wiki/Busan
# 2. snippet: 이상일=지역 산업의 고도화와 투자유치라는 두 가지 관점에서 살펴볼 필요가 있다. 울산 제조업의 실질 GRDP 부가가치는 2014년 72조4,000억원(전국 비중 4.48%)에서 2022년 69조2,000억원(전국 비중 3.51%)으로 감소했다. 고부가가치 제조 방식으로 전환하지 않으면 울산의 미래를..., title: [신년특집] "주력산업 고도화·신산업 육성 투트랙 전략 완성 위해 필수...", link: https://www.iusm.co.kr/news/articleView.html?idxno=1048188
# 3. snippet: 경기연구원의 자체 조사로는 경기도 내 투자가 10% 증가하면 경기도의 지역총생산(GRDP)이 3% 증가하고 국가 전체 GRDP는 5% 증가한다는 연구 결과가 나오기도 했다., title: [월간중앙-경기도경제단체연합회 공동기획 ] 기업기업의 생존조건..., link: https://www.m-joongang.com/news/articleView.html?idxno=307846
# 4. snippet: 통계청에 따르면 울산의 1인당 지역내총생산(GRDP)은 2023년 기준 8천124만원으로 전국 1위다. 자동차·조선·석유화학 등 대규모 제조산업이 집중된 도시의 생산성과 부가가치는 압도적이다., title: [창간 18주년 특집]울산, 꺼지지 않는 빛으로 대한민국 심야경제 견인, link: http://www.ujeil.com/news/articleView.html?idxno=376433
#
# ----- WEB SEARCH -----
# 통계청 부산 GRDP 전국 비중 2022 2023
# w
# 1. snippet: 7일 전 · 용인시(龍仁市)는 대한민국 경기도 동남부에 있는 특례시이다. 동쪽으로 이천시, 서쪽으로 수원시·의왕시·화성시, 남쪽으로 평택시·안성시, 북쪽은 성남시·광주시와 ..., title: 용인시 - 위키백과, 우리 모두의 백과사전, link: https://ko.wikipedia.org/wiki/용인시
# 2. snippet: 20시간 전 · 이른바 '재량적 소비' 업종 비중이 전국 3번째로 높아 물가 충격에 상대적으로 ... 부산 서비스업의 실질 GRDP 둔화 폭도 전국 평균보다 더 크게 나타났습니다., title: 동남지방통계청에 따르면 5월 기준 부산지역 고용률이 58.6%를 기록해 ..., link: https://www.instagram.com/reel/DZd9x27Nvac/
# 3. snippet: 2일 전 · ... 부산은 완전히 3차 산업 중심으로 산업 구조가 재편되었다. 2015년 기준으로 부산의 3차 산업이 GRDP에서 차지하는 비중은 전국 시·도 단위에서 서울, 대전에 이은 3위다., title: 부산광역시 - 나무위키, link: https://namu.wiki/w/부산광역시
# 4. snippet: 2일 전 · 지역내총생산(GRDP)은 2023년 기준 73조원으로 전국의 3% 수준에 머물렀고 1인당 GRDP 역시 3099만원으로 전국 평균(4649만원)보다 1500만원 가까이 낮았다. 서울로 ..., title: '격전지' 급부상 대구…시민들이 차기 대구시장에 바라는 것은 [민심 르포], link: https://www.kukinews.com/article/view/kuk202605060175
# Update from node research_agent:
#
#
# ================================= Tool Message =================================
# Name: transfer_back_to_supervisor
#
# Successfully transferred back to supervisor
#
#
# Update from node supervisor:
#
#
# ================================== Ai Message ==================================
# Name: supervisor
#
# [{'type': 'text', 'text': '부산의 경제 규모(GRDP)가 대한민국 전체 GDP에서 차지하는 비중은 **약 3% 수준**입니다.\n\n2025년 기준 한국의 정확한 명목 GDP 총액은 연말 결산 및 통계 발표에 따라 변동될 수 있는 예측치이므로, 공식적인 국가통계포털(KOSIS)의 확정치를 확인하시는 것을 권장합니다. 현재까지 알려진 경제 지표들을 종합하면 부산의 비중은 전국 대비 약 3% 내외를 유지하고 있습니다.', 'extras': {'signature': 'EjQKMgEMOdbHsN8TIlsBoEaUZbJNlNh6rKMKRdWbyzUgFdN4epKyhQPIJj8+NekjzJ5RliaY'}}]

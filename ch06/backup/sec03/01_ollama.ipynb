# %% [markdown]
# > LangChain Ollama: <https://docs.langchain.com/oss/python/integrations/providers/ollama>

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

# %%
template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="gemma3:270m", base_url="http://localhost:11434") # 도커를 이용하고 있으므로 base_url을 지정해주어야 함

chain = prompt | model

answer = chain.invoke({"question": "What is LangChain? Speak in Korean!"})

# %%
print(answer)
# Out:
# 안녕하세요! LangChain은 프로그래밍 언어의 핵심적인 도구입니다.
#
# **Step 1: 기본 개념 이해**
#
# *   LangChain은 **프로그래밍 언어의 추론과 활용**을 위한 도구입니다.
# *   특정 언어 (예: Python, Java, JavaScript 등)에서 특정 작업을 수행하는 데 사용됩니다.
# *   LangChain은 **프로그래밍 언어의 이해를 돕는 강력한 도구**입니다.
#
# **Step 2: LangChain의 주요 기능**
#
# *   **모델링:** LangChain은 **이미지 기반의 모델링**을 지원합니다.  쉽게 코드를 작성하고, 모델을 학습시키고, 결과를 예측할 수 있습니다.
# *   **반복적인 작업:**  데이터를 훈련, 테스트, 검증, 디버깅 등 다양한 작업을 수행할 수 있습니다.
# *   **데이터 저장 및 관리:**  데이터를 저장하고 관리하는 데 필요한 기능을 제공합니다.
# *   **실시간 처리:**  실시간으로 데이터를 처리할 수 있습니다.
# *   **자동화:**  자동화된 작업을 수행할 수 있도록 도와줍니다.
#
# **Step 3: LangChain의 활용 분야**
#
# *   **데이터 분석 및 머신러닝:**  데이터를 분석하고 예측하는 데 활용됩니다.
# *   **챗봇 및 가상 비서:**  챗봇이나 가상 비서를 개발하고 운영하는 데 사용됩니다.
# *   **자동화:**  자동화된 작업을 수행하는 데 사용됩니다.
# *   **데이터 시각화:**  데이터를 시각적으로 표현하는 데 활용됩니다.
# *   **코드 생성 및 검증:**  코드를 생성하고 검증하는 데 사용됩니다.
#
# **Step 4: LangChain의 장점**
#
# *   **간단하고 이해하기 쉬운 인터페이스:**  대부분의 사용자가 쉽게 이해할 수 있습니다.
# *   **다양한 모델링 옵션:**  이미지 기반, 숫자 기반,  데이터 기반 등 다양한 모델링 옵션을 제공합니다.
# *   **자동화:**  자동화된 작업을 수행하여 효율성을 높입니다.
# *   **데이터 저장 및 관리:**  데이터를 저장하고 관리하는 데 용이합니다.
# *   **실시간 처리:**  실시간으로 데이터를 처리할 수 있습니다.
#
# **Step 5: LangChain의 단점**
#
# *   **초기 설정 및 사용법:**  초기 설정 및 사용법이 복잡할 수 있습니다.
# *   **모델링에 대한 이해 필요:**  모델링에 대한 이해가 필요합니다.
# *   **데이터 저장 및 관리:**  데이터를 저장하고 관리하는 데 어려움이 있을 수 있습니다.
#
# **Step 6: LangChain의 미래**
#
# *   **더욱 발전된 모델링:**  더 복잡하고 다양한 모델링 옵션을 제공할 것입니다.
# *   **더욱 강력한 데이터 저장 및 관리:**  더욱 강력한 데이터 저장 및 관리 기능을 제공할 것입니다.
# *   **더욱 효율적인 자동화:**  더욱 효율적인 자동화 작업을 수행할 것입니다.
# *   **더욱 간편한 사용법:**  더 간편한 사용법을 제공할 것입니다.
#
# **결론**
#
# LangChain은 프로그래밍 언어의 추론과 활용을 위한 강력한 도구입니다.  다양한 분야에서 활용될 수 있으며,  더욱 발전된 모델링 옵션과 강력한 데이터 저장 및 관리 기능을 제공하여 사용자의 개발 업무 효율성을 높일 것입니다.
#
# 궁금궁금하는 점이 있다면, 어떤 분야에 관심이 있으신가요?  궁금한 점을 알려주시면 더 자세한 답변을 드릴 수 있습니다.

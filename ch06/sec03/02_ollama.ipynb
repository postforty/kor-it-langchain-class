# %% [markdown]
# > LangChain Ollama: <https://python.langchain.com/docs/integrations/llms/ollama/>

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

# %%
template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="gemma3n:latest", base_url="http://localhost:11434") # 도커를 이용하고 있으므로 base_url을 지정해주어야 함

chain = prompt | model

answer = chain.invoke({"question": "What is LangChain? Speak in Korean!"})

# %%
answer
# Out:
# '## LangChain 이란 무엇인가요? (What is LangChain?)\n\n자, 단계별로 생각해 봅시다. (Let\'s think step by step.)\n\nLangChain은 **대규모 언어 모델(LLM)을 활용하여 다양한 애플리케이션을 구축하는 데 도움을 주는 프레임워크**입니다. 쉽게 말해, LLM (예: ChatGPT, GPT-4)을 더 강력하고 유용하게 사용할 수 있도록 만들어주는 도구 모음이라고 할 수 있습니다.\n\n**좀 더 자세히 설명하면:**\n\n* **LLM과의 연결:** LangChain은 LLM과 다양한 데이터 소스 (예: 문서, 데이터베이스, API)를 연결하는 데 유용한 기능을 제공합니다.\n* **체인(Chain) 구성:** 여러 개의 LLM 호출 및 다른 도구들을 연결하여 복잡한 작업을 수행하는 "체인"을 만들 수 있습니다. 예를 들어, 질문에 답하기 위해 먼저 관련 문서를 검색하고, 그 문서를 LLM에 입력하여 답변을 생성하는 체인을 만들 수 있습니다.\n* **다양한 기능 제공:** 텍스트 분할, 임베딩, 프롬프트 관리, 메모리 관리 등 LLM 애플리케이션 개발에 필요한 다양한 기능을 제공합니다.\n* **커뮤니티 지원:** 활발한 오픈 소스 커뮤니티를 가지고 있어, 다양한 예제와 튜토리얼을 쉽게 찾을 수 있습니다.\n\n**LangChain을 사용하면 다음과 같은 것들을 할 수 있습니다:**\n\n* **챗봇 구축:** 사용자 질문에 답변하고 대화하는 챗봇을 만들 수 있습니다.\n* **문서 요약:** 긴 문서를 자동으로 요약할 수 있습니다.\n* **질의 응답 시스템:** 특정 문서나 데이터베이스에서 질문에 대한 답변을 찾을 수 있습니다.\n* **데이터 분석:** LLM을 활용하여 데이터를 분석하고 인사이트를 얻을 수 있습니다.\n\n**요약하자면, LangChain은 LLM을 활용한 애플리케이션 개발을 더 쉽고 효율적으로 만들어주는 강력한 도구입니다.**\n\n(In summary, LangChain is a powerful framework that makes it easier and more efficient to develop applications that utilize LLMs.)\n\n\n\n---\n\n**한국어 용어:**\n\n* **대규모 언어 모델 (LLM):** Large Language Model\n* **프레임워크:** Framework\n* **체인 (Chain):** Chain\n* **임베딩 (Embedding):** Embedding\n* **프롬프트 (Prompt):** Prompt\n* **메모리 (Memory):** Memory\n\n\n\n'

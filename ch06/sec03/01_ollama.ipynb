# %% [markdown]
# > LangChain Ollama: <https://python.langchain.com/docs/integrations/llms/ollama/>

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

# %%
template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="gemma3:latest", base_url="http://localhost:11434") # 도커를 이용하고 있으므로 base_url을 지정해주어야 함

chain = prompt | model

answer = chain.invoke({"question": "What is LangChain? Speak in Korean!"})

# %%
print(answer)
# Out:
# Okay, here’s an explanation of LangChain in Korean, broken down step-by-step:
#
# **LangChain이란 무엇일까요? (What is LangChain?)**
#
# **1단계: 배경 설명 (Background Explanation)**
#
# LangChain은 크게 두 가지 핵심적인 문제점을 해결하기 위해 만들어진 프레임워크입니다.  AI 모델, 특히 대규모 언어 모델(Large Language Models, LLM)과 상호 작용하는 방식에 있어서의 어려움을 해결하는 데 집중합니다.
#
# * **LLM과의 상호 작용의 어려움:** LLM들은 강력하지만,  단순히 텍스트를 생성하는 것 이상으로, 실제적인 작업을 수행하기 위해서는 더 많은 노력이 필요합니다.  예를 들어, 외부 데이터에 연결하거나, 여러 단계를 거쳐서 추론하고, 기억하는 등의 기능이 필요합니다.
# * **복잡한 개발:** LLM을 활용한 애플리케이션을 개발하는 것은 매우 복잡하고 어렵습니다.  각각의 LLM API를 직접 사용하는 것은 코드의 중복, 유지보수 어려움, 그리고 다양한 LLM의 차이점을 다루는 데 많은 시간을 소요합니다.
#
# **2단계: LangChain의 핵심 기능 (Key Features)**
#
# LangChain은 이러한 어려움을 해결하기 위해 다음과 같은 핵심 기능을 제공합니다.
#
# * **체인 (Chains):** LangChain의 가장 중요한 개념입니다.  체인은 LLM을 호출하고, 그 결과를 다른 기능과 연결하여 복잡한 작업을 수행하는 일련의 단계들을 의미합니다.  예를 들어, 질문을 받고, 관련 정보를 검색하고, 그 결과를 바탕으로 답변을 생성하는 과정이 하나의 체인으로 구성될 수 있습니다.
# * **프롬프트 템플릿 (Prompt Templates):**  LLM에게 전달할 프롬프트를 쉽게 관리하고 재사용할 수 있도록 해줍니다.  변수를 사용하여 프롬프트의 내용을 동적으로 변경할 수 있습니다.
# * **데이터 연결 (Data Connection):**  LLM이 외부 데이터 소스(데이터베이스, 웹사이트, API 등)에 접근하고 활용할 수 있도록 해줍니다.  이를 통해 LLM은 실시간 정보와 함께 작업을 수행할 수 있습니다.
# * **메모리 (Memory):**  LLM이 이전 대화 내용을 기억하고 활용할 수 있도록 해줍니다.  이를 통해 더 자연스럽고 맥락에 맞는 대화가 가능합니다.
#
# **3단계: 요약 (Summary)**
#
# LangChain은 LLM을 활용한 애플리케이션 개발을 더 쉽고 효율적으로 만들어주는 프레임워크입니다. 체인, 프롬프트 템플릿, 데이터 연결, 메모리 등 다양한 기능을 제공하여 LLM을 사용하여 복잡한 작업을 수행하고, 실제적인 애플리케이션을 개발할 수 있도록 돕습니다.
#
# ---
#
# **Translation of key phrases for reference:**
#
# * **LangChain:**  랭체인 (Rankchein)
# * **Large Language Models (LLM):** 대규모 언어 모델 (Daemul Unea Model)
# * **체인 (Chain):** 체인 (Chein)
# * **프롬프트 템플릿 (Prompt Template):** 프롬프트 템플릿 (Peumpto Template)
# * **데이터 연결 (Data Connection):** 데이터 연결 (Deiteo Yeongyeol)
# * **메모리 (Memory):** 메모리 (Memory)
#
# Would you like me to elaborate on a specific aspect of LangChain, like a particular feature or its use cases?  Do you want me to explain it in a more conversational way?

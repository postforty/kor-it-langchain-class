# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents.middleware import before_agent
from langchain.messages import AIMessage

@before_agent(can_jump_to = ["end"])
def validate_agent(state, runtime):
    human_message = state["messages"][-1]
    if "금지어" in human_message.content:
        print("금지어 감지")
        return {
            "messages": [AIMessage(content="현재 금지어가 포함되어 있습니다. 주의하세요.")],
            "jump_to": "end"
        }
    return None

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="google_genai:gemini-3.1-flash-lite", 
    middleware=[validate_agent],
)

# %%
agent.invoke(
    {"messages": [{"role": "user", "content": "이런 금지어 같은 경우를 봤나."}]},
)
# Out:
# 금지어 감지
# {'messages': [HumanMessage(content='이런 금지어 같은 경우를 봤나.', additional_kwargs={}, response_metadata={}, id='d991ea34-1737-4d4f-9c1c-20a402adb035'),
#   AIMessage(content='현재 금지어가 포함되어 있습니다. 주의하세요.', additional_kwargs={}, response_metadata={}, id='8e66052e-462d-4e3c-8d5b-0c31dc843731', tool_calls=[], invalid_tool_calls=[])]}

# %%
agent.invoke(
    {"messages": [{"role": "user", "content": "이런 경우를 봤나."}]},
)
# Out:
# {'messages': [HumanMessage(content='이런 경우를 봤나.', additional_kwargs={}, response_metadata={}, id='16080211-e8a8-4ede-a899-14b253949a06'),
#   AIMessage(content=[{'type': 'text', 'text': '무슨 일이 있으셨나요? \n\n사람 사는 세상이다 보니 정말 상식 밖의 일이나, 영화 같은 상황을 겪게 될 때가 있죠. 지금 겪으신 일이 어떤 상황인지 말씀해 주시면, 제가 함께 고민해 드리고 공감해 드릴게요. \n\n말하기가 복잡하거나 답답한 상황이라면 편하게 풀어내 주세요. 듣고 함께 이야기 나누겠습니다.', 'extras': {'signature': 'EjQKMgEMOdbHgdNs+2oZ9A4/GD4HOX84Lx0OKOgvbm4ke9Cs7NeNCd0EyrXZyIYryNixk6xO'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e7abd-cd5e-79c1-a7b8-c8bda5902d7f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 87, 'total_tokens': 95, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ### 환경 변수 설정

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# gemini_api_key = os.getenv("GEMINI_API_KEY")
# Out:
# True

# %% [markdown]
# ### 랭체인 Google Generative AI 연동
#
# > 랭체인 공식 문서 예제: <https://docs.langchain.com/oss/python/integrations/chat/google_generative_ai>

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    temperature=0.0, 
    # google_api_key=gemini_api_key
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Korean. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content='저는 프로그래밍을 사랑해요.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--80513ec2-6be7-4d9f-8beb-70de7ed2a647-0', usage_metadata={'input_tokens': 21, 'output_tokens': 8, 'total_tokens': 29, 'input_token_details': {'cache_read': 0}})

# %%
ai_msg.content
# Out:
# '저는 프로그래밍을 사랑해요.'

# %% [markdown]
# > 랭체인 공식 문서 예제: <https://python.langchain.com/docs/integrations/chat/google_generative_ai/#image-input>

# %% [markdown]
# ### 멀티모달 사용법 (Multimodal Usage)

# %% [markdown]
# #### ⚠️ langchain.messages를 import할 때 오류가 발생한다면...
#
# 1. Ctrl+Shift+P (또는 Cmd+Shift+P on Mac)
# 2. "Jupyter: Restart Kernel" 선택
# 3. 또는 노트북 상단의 재시작 버튼 클릭

# %%
import base64

from langchain.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

# Example using a public URL (remains the same)
message_url = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "Describe the image at the URL in Korean.", # 한국어로 답하도록 프롬프트 수정
        },
        {"type": "image_url", "image_url": "https://picsum.photos/seed/picsum/200/300"},
    ]
)

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    temperature=0, 
    # google_api_key=gemini_api_key
)

result_url = llm.invoke([message_url])
print(f"Response for URL image: {result_url.content}")
# Out:
# Response for URL image: 이 이미지는 눈 덮인 산의 웅장하고 고요한 풍경을 담고 있습니다.
#
# 하늘은 넓게 펼쳐진 파스텔톤의 구름으로 가득하며, 분홍색, 보라색, 연한 파란색이 어우러져 일출 또는 일몰의 아름다운 순간을 보여줍니다.
#
# 사진의 오른쪽에는 눈으로 뒤덮인 뾰족한 산봉우리가 솟아 있으며, 햇빛을 받아 밝게 빛나는 부분이 보입니다. 전경에는 부드러운 곡선을 이루는 어두운 푸른색 또는 보라색 계열의 눈밭이 넓게 펼쳐져 있어, 전체적으로 차분하면서도 신비로운 분위기를 자아냅니다.

# %%
# Example using a local image file encoded in base64
image_file_path = r"data\image.jpg"

with open(image_file_path, "rb") as image_file:
    encoded_image = base64.b64encode(image_file.read()).decode("utf-8")

message_local = HumanMessage(
    content=[
        {"type": "text", "text": "Describe the local image in Korean."}, # 한국어로 답하도록 프롬프트 수정
        {"type": "image_url", "image_url": f"data:image/png;base64,{encoded_image}"},
    ]
)
result_local = llm.invoke([message_local])
print(f"Response for local image: {result_local.content}")
# Out:
# Response for local image: 이 이미지는 빈센트 반 고흐의 유명한 유화 작품인 '별이 빛나는 밤(The Starry Night)'입니다.
#
# 전체적으로 강렬하고 몽환적인 밤 풍경을 묘사하고 있으며, 다음과 같은 요소들이 두드러집니다:
#
# 1.  **하늘 (상단):** 그림의 대부분을 차지하는 밤하늘은 깊고 푸른색 바탕에 노란색과 흰색의 별들이 빛나고 있습니다. 특히 오른쪽 상단에는 크고 밝은 초승달이 보이며, 하늘 전체에 걸쳐 소용돌이치는 듯한 역동적인 붓질이 특징입니다. 이 붓질은 하늘에 생동감과 움직임을 부여하며, 별들 주변의 후광과 함께 신비로운 분위기를 자아냅니다.
#
# 2.  **사이프러스 나무 (왼쪽 전경):** 그림의 왼쪽 전경에는 어둡고 거대한 사이프러스 나무가 하늘을 향해 솟아 있습니다. 이 나무는 불꽃처럼 위로 뻗어 있으며, 격정적인 밤하늘과 대조를 이루면서도 그림에 깊이와 수직적인 움직임을 더합니다.
#
# 3.  **마을 (하단 중앙):** 아래쪽에는 고요한 마을의 모습이 펼쳐져 있습니다. 작은 집들과 함께 뾰족한 교회 첨탑이 눈에 띄며, 몇몇 집에서는 따뜻한 불빛이 새어 나옵니다. 마을은 밤하늘의 격렬함과는 대조적으로 평화롭고 안정적인 느낌을 줍니다.
#
# 4.  **언덕/산 (배경):** 마을 뒤로는 어두운 푸른색의 완만한 언덕이나 산들이 배경을 이루고 있습니다. 이들은 마을과 하늘을 구분하는 경계 역할을 합니다.
#
# 반 고흐 특유의 두껍고 거친 붓질과 강렬한 색채 대비가 인상적이며, 보는 이에게 깊은 감동과 함께 밤의 신비로움을 전달하는 작품입니다.

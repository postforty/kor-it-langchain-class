# %%
import os
from dotenv import load_dotenv
load_dotenv()

# gemini_api_key = os.getenv("GEMINI_API_KEY")
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    # google_api_key=gemini_api_key
)

# %%
response = llm.invoke("대한민국의 수도는?")

# %%
response
# Out:
# AIMessage(content='대한민국의 수도는 **서울**입니다.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--35caebf5-c6de-4a14-aa11-25e029549d45-0', usage_metadata={'input_tokens': 7, 'output_tokens': 120, 'total_tokens': 127, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 110}})

# %%
response.content
# Out:
# '대한민국의 수도는 **서울**입니다.'

# %%
response.response_metadata
# Out:
# {'prompt_feedback': {'block_reason': 0, 'safety_ratings': []},
#  'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'safety_ratings': [],
#  'grounding_metadata': {},
#  'model_provider': 'google_genai'}

# %%
response.usage_metadata
# Out:
# {'input_tokens': 7,
#  'output_tokens': 120,
#  'total_tokens': 127,
#  'input_token_details': {'cache_read': 0},
#  'output_token_details': {'reasoning': 110}}

# %% [markdown]
# ### 창의성 설정

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    # 창의성 (0.0 ~ 2.0)
    # 기본값은 0.7
    # https://reference.langchain.com/python/langchain-google-genai/chat_models/ChatGoogleGenerativeAI
    temperature=0.0,
    # temperature=2.0,
    # google_api_key=gemini_api_key
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
response = llm.invoke(prompt)
response.content
# Out:
# 'LangChain 개발자인 나는 새로운 에이전트 구축에 몰두했다. 먼저 `PromptTemplate`으로 에이전트의 핵심 성격을 정의하고, `Memory`를 심어 과거 대화를 기억하게 했다. 여러 도구들을 정교하게 엮어 복잡한 `Chain`을 완성하니, 똑똑한 에이전트가 탄생했다.\n\n어느 날, 사무실 네트워크가 갑자기 마비되어 모두가 혼란에 빠졌다. 에이전트는 침착하게 "네트워크 진단 도구를 실행하고, 문제 해결 가이드를 찾아보겠습니다"라고 말하며, 스스로 진단 후 복구 절차를 안내했다. 예상치 못한 네트워크 장애였지만, 에이전트는 완벽하게 문제를 해결했다.'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    # 창의성 (0.0 ~ 2.0)
    # temperature=0.0, 
    temperature=2.0,
    # google_api_key=gemini_api_key
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
response = llm.invoke(prompt)
response.content
# Out:
# '새로운 에이전트를 꿈꿨다. 거대한 Chain으로 사고 흐름을 조립하고, 섬세한 PromptTemplate으로 말투와 역할을 주입했다. Memory 모듈로 과거를 기억하게 했지. 탄생한 에이전트.\n어느 날 갑자기 서버실 냉방기가 멈췄다. 나는 발을 동동 굴렀는데, 에이전트가 예상치 못하게 주변 장비 정보를 스스로 검색, 냉각팬을 풀가동해 시스템 과열을 막았다. 믿을 수 없군!'

# %% [markdown]
# ### 스트리밍 출력

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
)

# %%
response = llm.stream("Langchain에 대해 아주 쉽게 설명해줘.")

# %%
next(response) # 응답은 제너레이터
# Out:
# AIMessageChunk(content='랭체인(Langchain)은 "똑똑한 비서"를 만들어주는 도구라고 생각하시면 정말 쉬워요!\n\n---\n\n**아주 쉽게 비유하자면:**\n\nLLM (GPT-3, GPT', additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--764ec58e-a9b1-425a-82c3-bf12199c4b07', usage_metadata={'input_tokens': 11, 'output_tokens': 1635, 'total_tokens': 1646, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1586}})

# %%
next(response) # 응답은 제너레이터
# Out:
# AIMessageChunk(content="-4 같은 대규모 언어 모델)은 **정말 똑똑한 '뇌'** 같아요.\n*   말도 잘하고, 글도 잘 쓰고, 추리도 잘하죠.\n*   하지만 이 ", additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--764ec58e-a9b1-425a-82c3-bf12199c4b07', usage_metadata={'input_tokens': 0, 'output_tokens': 47, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}, 'total_tokens': 47})

# %%
for token in response:
    print(token.content, end="", flush=True) # flush=True 버퍼에 쌓인 내용을 즉시 강제로 출력(기본값은 False)
# Out:
# 뇌는 **혼자서는 할 수 없는 일들**이 있어요. 예를 들면:
#     *   "지금 서울 날씨가 어때?" (실시간 정보를 검색할 수 없음)
#     *   "어제 주식 시장 데이터 가져와서 분석해줘." (데이터베이스에 접근할 수 없음)
#     *   "내 친구에게 이메일 보내줘." (이메일 앱을 사용할 수 없음)
#
# 이때 **랭체인(Langchain)이 바로 이 똑똑한 뇌가 실제 세상과 소통하고, 더 많은 일을 할 수 있도록 도와주는 '연결 다리' 또는 '도우미' 역할을 합니다.**
#
# ---
#
# **랭체인이 하는 일 (똑똑한 비서가 하는 일):**
#
# 1.  **정보 찾아오기 (Tools):**
#     *   사용자가 "서울 날씨"를 물어보면, 랭체인이 날씨 앱이나 웹사이트 같은 **'도구(Tool)'**를 사용해서 정보를 찾아와 똑똑한 뇌(LLM)에게 전달해줘요. 그럼 뇌는 그 정보를 받아서 사용자에게 멋지게 설명해주는 거죠.
#     *   마치 비서가 "사장님, 지금 서울 날씨가 20도에 맑다고 합니다!" 하고 알려주는 것과 같아요.
#
# 2.  **여러 단계로 일 처리하기 (Chains):**
#     *   "어제 주식 시장 데이터를 가져와서, 중요한 뉴스 기사들을 요약하고, 내일 시장 전망을 예측해줘." 같은 복잡한 요청이 들어오면, 랭체인은 이걸 여러 단계로 나눠서 처리해요.
#         *   1단계: 주식 데이터베이스에서 데이터 가져오기 (도구 사용)
#         *   2단계: 뉴스 사이트에서 관련 기사 검색 및 요약 (도구 사용 + LLM의 요약 능력 활용)
#         *   3단계: 이 모든 정보를 종합해서 전망 예측 (LLM의 추리 능력 활용)
#     *   마치 비서가 복잡한 프로젝트를 계획하고, 필요한 자료를 모으고, 보고서까지 만들어서 사장님께 올리는 것과 같아요.
#
# 3.  **기억하기 (Memory):**
#     *   이전 대화 내용을 기억해서, "아까 말했던 그 프로젝트 진행 상황은 어때?"처럼 앞뒤 맥락이 있는 질문에도 자연스럽게 대답할 수 있게 해줘요.
#     *   비서가 사장님과의 지난 대화를 기억하고 있어서, 매번 처음부터 설명할 필요 없게 해주는 것과 비슷하죠.
#
# ---
#
# **결론적으로, 랭체인은:**
#
# LLM(똑똑한 뇌)이 단순한 대화만 하는 것을 넘어, **실제 세상의 정보를 찾아오고, 다른 프로그램과 연동하며, 복잡한 작업을 여러 단계로 나누어 처리할 수 있도록 만들어주는 '프레임워크' 또는 '도구 모음'** 입니다.
#
# 이 덕분에 개발자들은 랭체인을 사용해서, 마치 사람처럼 외부와 소통하고 행동하는 더 강력하고 유용한 AI 애플리케이션(챗봇, 자동화 시스템 등)을 쉽게 만들 수 있게 되는 거죠!

# %%
import os
from dotenv import load_dotenv
load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=gemini_api_key
)

# %%
response = llm.invoke("대한민국의 수도는?")

# %%
response
# Out:
# AIMessage(content='대한민국의 수도는 **서울**입니다.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--368b80aa-c27b-45c2-99a6-01f2d564c9ec-0', usage_metadata={'input_tokens': 7, 'output_tokens': 140, 'total_tokens': 147, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 130}})

# %%
response.content
# Out:
# '대한민국의 수도는 **서울**입니다.'

# %%
response.response_metadata
# Out:
# {'prompt_feedback': {'block_reason': 0, 'safety_ratings': []},
#  'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'safety_ratings': [],
#  'grounding_metadata': {},
#  'model_provider': 'google_genai'}

# %%
response.usage_metadata
# Out:
# {'input_tokens': 7,
#  'output_tokens': 89,
#  'total_tokens': 96,
#  'input_token_details': {'cache_read': 0},
#  'output_token_details': {'reasoning': 76}}

# %% [markdown]
# ### 창의성 설정

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    # 창의성 (0.0 ~ 2.0)
    temperature=0.0, 
    # temperature=2.0,
    google_api_key=gemini_api_key
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
response = llm.invoke(prompt)
response.content
# Out:
# "새로운 에이전트, '오로라'를 구축했다. `PromptTemplate`으로 명확한 임무와 성격을 부여하고, 복잡한 추론 `Chain`으로 사고 과정을 엮었다. `Memory`를 심어 대화 맥락과 과거 데이터를 기억하게 했다. 막바지 테스트 중, 갑자기 연구실 전력 시스템에 이상이 감지되었다. 오로라는 즉시 과거 전력 사용 패턴과 시스템 로그를 분석, 예상치 못한 과부하 원인을 찾아내고, 비상 전력 전환 절차를 정확히 지시하여 대형 사고를 막았다. 모두가 경이로워했다."

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    # 창의성 (0.0 ~ 2.0)
    # temperature=0.0, 
    temperature=2.0,
    google_api_key=gemini_api_key
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
response = llm.invoke(prompt)
response.content
# Out:
# "낡은 시스템이 오류에 허덕일 때, 나는 새로운 에이전트를 설계했습니다. 먼저, 그 정체성을 'PromptTemplate'에 심었죠. 이후 여러 판단 단계를 정교하게 엮어 튼튼한 'Chain'을 구축하고, 장기적인 대화 맥락을 기억하도록 'Memory'를 부여했습니다. 시험 가동 중 갑자기 예기치 않은 시스템 마비가 닥쳤을 때, 나의 에이전트는 미지의 네트워크 암호화를 순식간에 풀어내고 데이터 유출을 막아냈습니다. 본래의 목표를 넘어선 놀라운 활약이었죠."

# %% [markdown]
# ### 스트리밍 출력

# %%
response = llm.stream("Langchain에 대해 아주 쉽게 설명해줘.")

# %%
next(response) # 응답은 제너레이터
# Out:
# AIMessageChunk(content="랭체인(Langchain)은 쉽게 말해, **아주 똑똑한 '뇌'만 가지고 있는 인공지능(LLM)에게 '팔다리'와 '도구'를 달아주어 실제 세상에서", additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--99b3f28d-75d9-4a2f-8068-75211959692e', usage_metadata={'input_tokens': 10, 'output_tokens': 1763, 'total_tokens': 1773, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1712}})

# %%
next(response) # 응답은 제너레이터
# Out:
# AIMessageChunk(content=" 뭔가 유용한 일을 할 수 있게 도와주는 '만능 도구 상자'**라고 생각하시면 됩니다.\n\n---\n\n**아주 쉬운 비유:**\n\n상상해보세요. 엄청나게 똑똑한 천재 한", additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--99b3f28d-75d9-4a2f-8068-75211959692e', usage_metadata={'output_token_details': {'reasoning': 0}, 'input_tokens': 0, 'total_tokens': 50, 'input_token_details': {'cache_read': 0}, 'output_tokens': 50})

# %%
for token in response:
    print(token.content, end="", flush=True) # flush=True 버퍼에 쌓인 내용을 즉시 강제로 출력(기본값은 False)
# Out:
#  명을 모셔왔다고 칩시다. 이 천재는 무엇이든 논리적으로 생각하고, 방대한 지식을 조합해서 글을 쓰고, 요약하는 등 머리로 할 수 있는 건 다 잘해요.
#
# 그런데 이 천재가 다음과 같은 일을 하려고 하면 혼자서는 어려울 겁니다.
# 1.  **"어제 내가 했던 말을 기억해?"** (대화의 맥락을 기억하는 것)
# 2.  **"지금 시카고 날씨가 어때?"** (최신 웹 정보를 찾아보는 것)
# 3.  **"내가 가진 이 PDF 파일을 읽고 요약해 줘."** (본인이 학습한 지식 외의 새로운 문서를 참고하는 것)
# 4.  **"계산기를 써서 이 복잡한 계산을 해줘."** (계산기 같은 외부 도구를 사용하는 것)
# 5.  **"1단계: 내 파일 읽고 → 2단계: 핵심 요약 후 → 3단계: 이메일 초안 작성해 줘."** (여러 단계를 거쳐 작업하는 것)
#
# 천재 혼자서는 '생각'은 할 수 있지만, 정보를 찾고, 도구를 쓰고, 여러 작업을 체계적으로 연결하는 '실행' 능력은 없죠.
#
# **바로 여기서 '랭체인(Langchain)'이 등장합니다!**
#
# ---
#
# **랭체인은 뭘 도와주나요?**
#
# 랭체인은 이런 '똑똑한 뇌(LLM)'가 우리 실제 세상에서 유용하게 움직일 수 있도록 필요한 다양한 부품들을 모아놓은 **레고 블록 세트** 같아요. 이 블록들을 조립해서 개발자들이 LLM을 활용한 다양한 앱을 더 쉽고 빠르게 만들 수 있게 해줍니다.
#
# 주요 기능은 다음과 같습니다:
#
# 1.  **LLM 연결 부품:** GPT-3.5, GPT-4, Gemini 등 여러 종류의 LLM 모델들과 쉽게 연결해서 쓸 수 있게 해줍니다.
# 2.  **정보 보강 부품 (Retrieval):** LLM이 본인이 학습한 지식 외에, 내가 가진 개인 파일, 데이터베이스, 웹 문서 등을 추가로 참고해서 답변하도록 도와줘요. (예: 최신 회사 내부 문서를 LLM에게 읽히고 질문하는 것)
# 3.  **도구 사용 부품 (Tools):** LLM이 웹 검색, 계산기, 외부 API, 프로그래밍 코드 등 다양한 도구들을 스스로 '사용'할 수 있게 만들어줍니다. (예: "내일 뉴욕 날씨 알려줘"라고 하면 LLM이 알아서 날씨 정보를 검색해서 답해주는 것)
# 4.  **여러 단계 작업 부품 (Chains):** "질문 파악 → 정보 검색 → 내용 요약 → 답변 생성"처럼 복잡한 질문이나 작업을 여러 단계로 쪼개서 차례대로 처리하도록 만들어줘요. 이 과정 자체를 '체인(Chain)'이라고 부릅니다.
# 5.  **대화 기억 부품 (Memory):** LLM이 이전에 했던 대화를 기억해서 다음 질문에 대한 답변을 더 맥락에 맞게 생성할 수 있게 해줍니다. 마치 챗봇이 나를 기억하는 것처럼요.
# 6.  **출력 형식 제어 부품 (Output Parsers):** LLM의 답변을 우리가 원하는 특정 형식(예: JSON, 목록 형태)으로 받아볼 수 있게 도와줘요.
#
# ---
#
# **결론적으로:**
#
# 랭체인은 **LLM이라는 똑똑한 두뇌에 '팔다리'와 '도구'를 달아주고, 여러 작업 지시를 효율적으로 연결해 주어 실제로 세상에 나와 뭔가 유용한 일을 할 수 있게 만들어주는 프레임워크**입니다. 덕분에 개발자들은 더욱 강력하고 똑똑하며 실용적인 AI 애플리케이션을 훨씬 쉽고 빠르게 만들 수 있게 됩니다.
